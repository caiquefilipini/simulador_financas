# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel("base_indicadores.xlsx", sheet_name="indicadores", engine="openpyxl")
df.columns = df.columns.str.lower()

# %%
df.loc[df["indicador"] == "cascada_ppto", "topico"] = "cascada"
df.loc[df["indicador"] == "cascada_ppto", "indicador"] = "ppto"

# %%
import unicodedata

def remover_acentos(texto):
    if isinstance(texto, str):
        nfkd = unicodedata.normalize("NFKD", texto)
        return "".join([char for char in nfkd if not unicodedata.combining(char)])
    return texto

# Tratando textos
df["abertura"] = df["abertura"].apply(remover_acentos)
df["abertura"] = df["abertura"].str.lower()
df["abertura"] = df["abertura"].str.replace(" ", "_")
df["abertura"] = df["abertura"].str.replace("-", "_")
df["abertura"] = df["abertura"].str.replace("(", "")
df["abertura"] = df["abertura"].str.replace(")", "")
df["abertura"] = df["abertura"].str.replace("/", "_")

df["topico"] = df["topico"].str.replace(" ", "_") # Off Balance

# %%
df[df["abertura"] == "rorwa"]
# Out:
# Empty DataFrame
# Columns: [topico, indicador, abertura, especial, prospera, select, pj, corporate, scib, private, consumer, total]
# Index: []

# %%
segmentos = ["especial", "prospera", "select", "pj", "corporate", "scib", "private", "consumer"]
df.loc[df["indicador"] == "spread", segmentos] = (df.loc[df["indicador"] == "spread", segmentos] * 100).round(2)
df.loc[df["abertura"].isin(["rorwa", "ppto_taxa_impositiva", "ppto_eficiencia"]), segmentos] = df.loc[df["abertura"].isin(["rorwa", "ppto_taxa_impositiva", "ppto_eficiencia"]), segmentos] * 100

# %%
# calculando o atingimento do cascada
indicadores_atingimento = df.loc[(df["indicador"] == "cascada") & (~df["abertura"].isin(["rwa", "rorwa"]))]["abertura"].unique()

realizado = df.loc[(df["indicador"] == "cascada") & (~df["abertura"].isin(["rwa", "rorwa"]))][segmentos + ['total']].reset_index(drop=True)
ppto = df.loc[(df["indicador"] == "ppto")][segmentos + ['total']].reset_index(drop=True)

resultado_divisao = (realizado / ppto * 100).fillna(0)

resultado_divisao["topico"] = "cascada"
resultado_divisao["indicador"] = "atingimento"
resultado_divisao["abertura"] = [f"atingimento_{i}" for i in indicadores_atingimento]

df = pd.concat([df, resultado_divisao[["topico", "indicador", "abertura"] + segmentos + ['total']]], ignore_index=True)

# %%
# calculando a taxa impositiva, eficiência e rorwa

mob = df.loc[(df["indicador"] == "cascada") & (df["abertura"].isin(["mob"]))][segmentos + ['total']].reset_index(drop=True).fillna(0)
gastos = df.loc[(df["indicador"] == "cascada") & (df["abertura"].isin(["total_gastos"]))][segmentos + ['total']].reset_index(drop=True).fillna(0)

bai = df.loc[(df["indicador"] == "cascada") & (df["abertura"].isin(["bai"]))][segmentos + ['total']].reset_index(drop=True).fillna(0)
impostos = df.loc[(df["indicador"] == "cascada") & (df["abertura"].isin(["impostos"]))][segmentos + ['total']].reset_index(drop=True).fillna(0)

bdi = df.loc[(df["indicador"] == "cascada") & (df["abertura"].isin(["bdi"]))][segmentos + ['total']].reset_index(drop=True).fillna(0)
rwa = df.loc[(df["indicador"] == "cascada") & (df["abertura"].isin(["rwa"]))][segmentos + ['total']].reset_index(drop=True).fillna(0)

eficiencia = round(-gastos / mob * 100, 1)
eficiencia["abertura"] = "eficiencia"
taxa_impositiva = round(-impostos / bai * 100, 1)
taxa_impositiva["abertura"] = "taxa_impositiva"
rorwa = round(bdi / rwa * 100, 2)
rorwa["abertura"] = "rorwa"

df_aux = pd.concat([eficiencia, taxa_impositiva, rorwa], ignore_index=True)
df_aux["indicador"] = "cascada"
df_aux["topico"] = "cascada"

df_aux = df_aux[["topico", "indicador", "abertura"] + segmentos + ['total']]
df = pd.concat([df, df_aux], ignore_index=True)

# %%
gastos
# Out:
#    especial  prospera  select      pj  corporate    scib  private  consumer  \
# 0   -5761.0    -453.0 -7507.0 -6565.0     -742.0 -2420.0   -520.0   -1148.0
#
#      total
# 0 -26129.0

# %%
bdi
# Out:
#    especial  prospera  select      pj  corporate    scib  private  consumer  \
# 0   -1735.0     176.0  2328.0  4675.0     3315.0  4518.0    388.0    1209.0
#
#      total
# 0  15236.0

# %%
rwa
# Out:
#    especial  prospera    select       pj  corporate      scib  private  \
# 0  41286.86   1143.07  59090.22  80276.0    99616.0  122660.0   6890.0
#
#    consumer     total
# 0   70232.0  600644.0

# %%
176.0 / 1143.07
# Out:
# 0.15397132284112086

# %%
rorwa
# Out:
#    especial  prospera  select    pj  corporate  scib  private  consumer  \
# 0      -4.2      15.4    3.94  5.82       3.33  3.68     5.63      1.72
#
#    total abertura
# 0   2.54    rorwa

# %%
for col in df.select_dtypes(include=['number']).columns:
    df[col] = df[col].round(2)

# %%
df[df["topico"] == "cascada"]
# Out:
#       topico    indicador                   abertura  especial  prospera  \
# 149  cascada      cascada                        mob  14768.00   1269.00
# 150  cascada      cascada                        pdd  -9698.00   -412.00
# 151  cascada      cascada                        mol   5070.00    857.00
# 152  cascada      cascada                       oryp   -972.00    -70.00
# 153  cascada      cascada              demais_ativos   -185.00     -1.00
# 154  cascada      cascada               total_gastos  -5761.00   -453.00
# 155  cascada      cascada                        bai  -1848.00    333.00
# 156  cascada      cascada                   impostos    113.00   -157.00
# 157  cascada      cascada                        bdi  -1735.00    176.00
# 158  cascada      cascada                        rwa  41286.86   1143.07
# 159  cascada         ppto                   ppto_mob  15351.00   1666.00
# 160  cascada         ppto                   ppto_pdd  -9771.00   -390.00
# 161  cascada         ppto                   ppto_mol   5580.00   1276.00
# 162  cascada         ppto                  ppto_oryp  -1298.00    -95.00
# 163  cascada         ppto         ppto_demais_ativos   -144.00     -8.00
# 164  cascada         ppto          ppto_total_gastos  -5717.00   -440.00
# 165  cascada         ppto                   ppto_bai   1579.00    733.00
# 166  cascada         ppto              ppto_impostos    -59.00   -277.00
# 167  cascada         ppto                   ppto_bdi   1638.00    456.00
# 168  cascada  atingimento            atingimento_mob     96.20     76.17
# 169  cascada  atingimento            atingimento_pdd     99.25    105.64
# 170  cascada  atingimento            atingimento_mol     90.86     67.16
# 171  cascada  atingimento           atingimento_oryp     74.88     73.68
# 172  cascada  atingimento  atingimento_demais_ativos    128.47     12.50
# 173  cascada  atingimento   atingimento_total_gastos    100.77    102.95
# 174  cascada  atingimento            atingimento_bai   -117.04     45.43
# 175  cascada  atingimento       atingimento_impostos   -191.53     56.68
# 176  cascada  atingimento            atingimento_bdi   -105.92     38.60
# 177  cascada      cascada                 eficiencia     39.00     35.70
# 178  cascada      cascada            taxa_impositiva      6.10     47.10
# 179  cascada      cascada                      rorwa     -4.20     15.40
#
#        select        pj  corporate       scib  private  consumer      total
# 149  18966.00  21408.00    6376.00    9229.00  1130.00   7218.00   81922.00
# 150  -6047.00  -5900.00    -579.00    -109.00    -4.00  -3751.00  -26529.00
# 151  12919.00  15508.00    5797.00    9120.00  1126.00   3467.00   55393.00
# 152   -834.00  -1073.00     -20.00     -19.00    -2.00   -307.00   -3107.00
# 153    -74.00    -11.00       0.00       0.00     0.00      0.00    -314.00
# 154  -7507.00  -6565.00    -742.00   -2420.00  -520.00  -1148.00  -26129.00
# 155   4504.00   7859.00    5035.00    6681.00   604.00   2012.00   25843.00
# 156  -2176.00  -3184.00   -1720.00   -2163.00  -216.00   -803.00  -10607.00
# 157   2328.00   4675.00    3315.00    4518.00   388.00   1209.00   15236.00
# 158  59090.22  80276.00   99616.00  122660.00  6890.00  70232.00  600644.00
# 159  18511.00  21926.00    6302.00    9113.00  1124.00   7268.00   82847.00
# 160  -5841.00  -5911.00    -493.00    -115.00   -15.00  -3811.00  -26349.00
# 161  12669.00  16014.00    5809.00    8998.00  1109.00   3457.00   56498.00
# 162   -479.00  -1093.00     -19.00     -21.00    -2.00   -297.00   -3130.00
# 163   -163.00   -220.00       0.00       0.00     0.00      0.00    -548.00
# 164  -7347.00  -6448.00    -803.00   -2308.00  -500.00  -1148.00  -25700.00
# 165   4680.00   8253.00    4987.00    6669.00   607.00   2012.00   27120.00
# 166  -2090.00  -3213.00   -1687.00   -2232.00  -215.00   -851.00  -10640.00
# 167   2590.00   5040.00    3300.00    4842.00   392.00   1161.00   16480.00
# 168    102.46     97.64     101.17     101.27   100.53     99.31      98.88
# 169    103.53     99.81     117.44      94.78    26.67     98.43     100.68
# 170    101.97     96.84      99.79     101.36   101.53    100.29      98.04
# 171    174.11     98.17     105.26      90.48   100.00    103.37      99.27
# 172     45.40      5.00       0.00       0.00     0.00      0.00      57.30
# 173    102.18    101.81      92.40     104.85   104.00    100.00     101.67
# 174     96.24     95.23     100.96     100.18    99.51    100.00      95.29
# 175    104.11     99.10     101.96      96.91   100.47     94.36      99.69
# 176     89.88     92.76     100.45      93.31    98.98    104.13      92.45
# 177     39.60     30.70      11.60      26.20    46.00     15.90      31.90
# 178     48.30     40.50      34.20      32.40    35.80     39.90      41.00
# 179      3.94      5.82       3.33       3.68     5.63      1.72       2.54

# %%
# df_melted = df.melt(id_vars=["Topico", "Indicador", "Abertura"], var_name="Segmento", value_name="Valor")

# %%
aberturas_segmento = {
    "credito": {
        "especial": ['cheque especial', 'cartões', 'cp', 'consignado', 'hipotecas', 'autos', 'demais'],
        "prospera": ['cheque especial', 'cartões', 'cp', 'consignado', 'hipotecas', 'autos', 'microcrédito', 'demais'],
        "select": ['cheque especial', 'cartões', 'cp', 'consignado', 'hipotecas', 'autos', 'agro', 'comex', 'demais'],
        "pj": ['cheque emp/adp', 'cartões', 'hipotecas', 'autos', 'agro', 'capital de giro', 'comex', 'conta garantida', 'confirming', 'internegócios', 'demais'],
        "corporate": ['hipotecas', 'autos', 'agro', 'capital de giro', 'comex', 'conta garantida', 'confirming', 'internegócios', 'demais'],
        "scib": ['cartões', 'hipotecas', 'autos', 'agro', 'capital de giro', 'comex', 'confirming', 'internegócios', 'demais'],
        "private": ['cartões', 'cp', 'hipotecas', 'autos', 'agro', 'capital de giro', 'comex', 'internegócios', 'demais'],
        "consumer": ['cp', 'autos', 'demais']
    },

    "captacoes": {
        "especial": ['dav', 'contamax', 'cdb', 'poupança', 'letras', 'demais'],
        "prospera": ['dav', 'contamax', 'cdb', 'poupança', 'letras', 'demais'],
        "select": ['dav', 'contamax', 'cdb', 'poupança', 'letras', 'captações comex', 'demais'],
        "pj": ['dav', 'contamax', 'cdb', 'poupança', 'letras', 'captações comex', 'time deposit', 'demais'],
        "corporate": ['dav', 'contamax', 'cdb', 'letras', 'captações comex', 'time deposit', 'demais'],
        "scib": ['dav', 'contamax', 'cdb', 'letras', 'captações comex', 'time deposit', 'lf', 'demais'],
        "private": ['dav', 'contamax', 'cdb', 'letras', 'captações comex', 'coe', 'demais'],
        "consumer": []
    },

    "comissoes": {
        "especial": ['cartões', 'seguros open', 'seguros related', 'tarifas c/c', 'capitalização', 'consórcio', 'esfera', 'fidelização inss', 'tecban', 'demais'],
        "prospera": ['cartões', 'seguros open', 'seguros related', 'tarifas c/c', 'capitalização', 'consórcio', 'esfera', 'fidelização inss', 'tecban', 'demais'],
        "select": ['cartões', 'seguros open', 'seguros related', 'tarifas c/c', 'capitalização', 'consórcio', 'esfera', 'tecban', 'aaa', 'demais'],
        "pj": ['cartões', 'seguros open', 'seguros related', 'tarifas c/c', 'capitalização', 'consórcio', 'esfera', 'tecban', 'abertura conta', 'adquirência', 'fx', 'cash', 'demais'],
        "corporate": ['cartões', 'seguros open', 'seguros related', 'tarifas c/c', 'capitalização', 'consórcio', 'mercado de capitais', 'fiança', 'abertura conta', 'adquirência', 'fx', 'cash', 'demais'],
        "scib": ['mercado de capitais', 'fx', 'fiança', 'comex', 'cash', 'corretagem', 'demais'],
        "private": ['previdência', 'fundos', 'fx', 'mercado de capitais', 'comex', 'esfera', 'cartões', 'demais'],
        "consumer": ['seguros open', 'seguros related', 'tarifas de crédito', 'demais']
    }
}

# %%
for k in aberturas_segmento:
    for abertura in aberturas_segmento[k]:
        aberturas_segmento[k][abertura] = [i.replace(" ", "_") for i in aberturas_segmento[k][abertura]]
        aberturas_segmento[k][abertura] = [i.replace("/", "") for i in aberturas_segmento[k][abertura]]
        aberturas_segmento[k][abertura] = [remover_acentos(i) for i in aberturas_segmento[k][abertura]]

# %%
def calculate_spread(df, segmentos):
    new_spread = pd.DataFrame(
        np.array(
            df.loc[df["indicador"] == "margem"][segmentos].astype("float")) /
             np.array(df.loc[df["indicador"] == "carteira"][segmentos].astype("float")) * 100,
        columns=segmentos
    ).fillna(0)
    df.loc[df["indicador"] == "spread", segmentos] = np.array(new_spread)
    return df

# %%
def get_numbers(df, topico, indicador, segmento, aberturas_segmento):
    new_df = df.loc[(df["topico"] == topico) & (df["indicador"] == indicador), ["abertura", segmento]]
    if topico not in ["cascada"]:
        if segmento in ["especial", "prospera", "select"]:
            new_df["abertura"] = new_df["abertura"].apply(lambda x: "cheque_especial" if x == "cheque" else x)
        elif segmento == "PJ":
            new_df["abertura"] = new_df["abertura"].apply(lambda x: "cheque_empadp" if x == "cheque" else x)
        if segmento != "total":
            new_df["abertura"] = new_df["abertura"].apply(lambda x: x if x in aberturas_segmento[topico][segmento] else "demais")
    else:
        new_df = df.loc[(df["topico"] == topico) & (df["indicador"] == indicador), ["abertura", segmento]]
    return new_df.groupby(["abertura"])[segmento].sum().to_dict()

# %%
df[df["abertura"] == "rorwa"]
# Out:
#       topico indicador abertura  especial  prospera  select    pj  corporate  \
# 179  cascada   cascada    rorwa      -4.2      15.4    3.94  5.82       3.33
#
#      scib  private  consumer  total
# 179  3.68     5.63      1.72   2.54

# %%
get_numbers(df, "cascada", "cascada", "prospera", aberturas_segmento)
# indicador = ['cascada', 'ppto', 'atingimento']
# ['carteira', 'spread', 'provisao', 'margem', 'rwa']
# Out:
# {'bai': 333.0,
#  'bdi': 176.0,
#  'demais_ativos': -1.0,
#  'eficiencia': 35.7,
#  'impostos': -157.0,
#  'mob': 1269.0,
#  'mol': 857.0,
#  'oryp': -70.0,
#  'pdd': -412.0,
#  'rorwa': 15.4,
#  'rwa': 1143.07,
#  'taxa_impositiva': 47.1,
#  'total_gastos': -453.0}

# %%
topicos = df["topico"].unique()
segmentos = ["especial", "prospera", "select", "pj", "corporate", "scib", "private", "consumer", "total"]
segmentos = [s.lower() for s in segmentos]
indicadores = df.groupby("topico")["indicador"].unique().to_dict()
indicadores_cascada = df.loc[df["topico"] == "cascada", "abertura"].unique()
# indicadores_cascada_ppto = df.loc[df["topico"] == "cascada_ppto", "abertura"].unique()

# %%
topicos
# Out:
# array(['credito', 'comissoes', 'captacoes', 'off_balance', 'cascada'],
#       dtype=object)

# %%
indicadores
# Out:
# {'captacoes': array(['spread', 'carteira', 'margem'], dtype=object),
#  'cascada': array(['cascada', 'ppto', 'atingimento'], dtype=object),
#  'comissoes': array(['comissoes'], dtype=object),
#  'credito': array(['carteira', 'spread', 'provisao', 'margem', 'rwa'], dtype=object),
#  'off_balance': array(['spread', 'carteira', 'margem'], dtype=object)}

# %%
segmentos
# Out:
# ['especial',
#  'prospera',
#  'select',
#  'pj',
#  'corporate',
#  'scib',
#  'private',
#  'consumer',
#  'total']

# %%
dict_indicadores = dict()
for segmento in segmentos:
    dict_indicadores[segmento] = {}
    for topico in topicos:
        if (topico == "off_balance") | (segmento == "total" and topico != "cascada"):
            continue
        dict_indicadores[segmento][topico] = {}
        for indicador in indicadores[topico]:
            dict_resultado = get_numbers(df, topico, indicador, segmento, aberturas_segmento)

            if topico == ["comissoes"]:
                dict_indicadores[segmento][topico] = dict_resultado
            else:
                dict_indicadores[segmento][topico][indicador] = dict_resultado

# %%
dict_indicadores
# Out:
# {'especial': {'credito': {'carteira': {'autos': 4970.0,
#     'cartoes': 20157.0,
#     'cheque_especial': 1747.0,
#     'consignado': 38458.0,
#     'cp': 6964.0,
#     'demais': 67.0,
#     'hipotecas': 11632.0},
#    'spread': {'autos': 9.37,
#     'cartoes': 17.02,
#     'cheque_especial': 89.48,
#     'consignado': 8.57,
#     'cp': 22.33,
#     'demais': 50.29,
#     'hipotecas': 1.47},
#    'provisao': {'autos': -380.0,
#     'cartoes': -3317.0,
#     'cheque_especial': -477.0,
#     'consignado': -1957.0,
#     'cp': -2917.0,
#     'demais': -22.0,
#     'hipotecas': -68.0},
#    'margem': {'autos': 465.7,
#     'cartoes': 3430.7,
#     'cheque_especial': 1563.2,
#     'consignado': 3295.9,
#     'cp': 1555.1,
#     'demais': 18.0,
#     'hipotecas': 171.0},
#    'rwa': {'autos': 3519.0,
#     'cartoes': 7841.0,
#     'cheque_especial': 1067.0,
#     'consignado': 22553.0,
#     'cp': 2496.0,
#     'demais': 28.0,
#     'hipotecas': 3579.0}},
#   'comissoes': {'comissoes': {'capitalizacao': 448.0,
#     'cartoes': 1654.0,
#     'demais': 1822.0,
#     'esfera': 33.0,
#     'fidelizacao_inss': 266.0,
#     'seguros_open': 597.0,
#     'seguros_related': 491.0,
#     'tecban': 0.0}},
#   'captacoes': {'spread': {'cdb': 0.54,
#     'contamax': 12.65,
#     'dav': 6.29,
#     'demais': 11.719999999999999,
#     'letras': 0.71,
#     'poupanca': 1.67},
#    'carteira': {'cdb': 5517.0,
#     'contamax': 11509.0,
#     'dav': 706.0,
#     'demais': 859.0,
#     'letras': 800.0,
#     'poupanca': 18838.0},
#    'margem': {'cdb': 29.8,
#     'contamax': 1455.9,
#     'dav': 44.4,
#     'demais': 27.5,
#     'letras': 5.7,
#     'poupanca': 314.6}},
#   'cascada': {'cascada': {'bai': -1848.0,
#     'bdi': -1735.0,
#     'demais_ativos': -185.0,
#     'eficiencia': 39.0,
#     'impostos': 113.0,
#     'mob': 14768.0,
#     'mol': 5070.0,
#     'oryp': -972.0,
#     'pdd': -9698.0,
#     'rorwa': -4.2,
#     'rwa': 41286.86,
#     'taxa_impositiva': 6.1,
#     'total_gastos': -5761.0},
#    'ppto': {'ppto_bai': 1579.0,
#     'ppto_bdi': 1638.0,
#     'ppto_demais_ativos': -144.0,
#     'ppto_impostos': -59.0,
#     'ppto_mob': 15351.0,
#     'ppto_mol': 5580.0,
#     'ppto_oryp': -1298.0,
#     'ppto_pdd': -9771.0,
#     'ppto_total_gastos': -5717.0},
#    'atingimento': {'atingimento_bai': -117.04,
#     'atingimento_bdi': -105.92,
#     'atingimento_demais_ativos': 128.47,
#     'atingimento_impostos': -191.53,
#     'atingimento_mob': 96.2,
#     'atingimento_mol': 90.86,
#     'atingimento_oryp': 74.88,
#     'atingimento_pdd': 99.25,
#     'atingimento_total_gastos': 100.77}}},
#  'prospera': {'credito': {'carteira': {'autos': 184.0,
#     'cartoes': 182.0,
#     'cheque_especial': 18.0,
#     'consignado': 1494.0,
#     'cp': 44.0,
#     'demais': 0.0,
#     'hipotecas': 107.0,
#     'microcredito': 2719.0},
#    'spread': {'autos': 9.25,
#     'cartoes': 17.73,
#     'cheque_especial': 92.84,
#     'consignado': 6.89,
#     'cp': 22.62,
#     'demais': 0.0,
#     'hipotecas': 1.52,
#     'microcredito': 36.11},
#    'provisao': {'autos': -28.0,
#     'cartoes': -181.0,
#     'cheque_especial': -10.0,
#     'consignado': -96.0,
#     'cp': -34.0,
#     'demais': 0.0,
#     'hipotecas': 0.0,
#     'microcredito': -213.0},
#    'margem': {'autos': 17.0,
#     'cartoes': 32.3,
#     'cheque_especial': 16.7,
#     'consignado': 102.9,
#     'cp': 10.0,
#     'demais': 0.0,
#     'hipotecas': 1.6,
#     'microcredito': 981.8},
#    'rwa': {'autos': 130.0,
#     'cartoes': 71.0,
#     'cheque_especial': 11.0,
#     'consignado': 876.0,
#     'cp': 16.0,
#     'demais': 0.0,
#     'hipotecas': 33.0,
#     'microcredito': 1411.0}},
#   'comissoes': {'comissoes': {'capitalizacao': 12.0,
#     'cartoes': 76.0,
#     'demais': 37.0,
#     'esfera': 0.0,
#     'fidelizacao_inss': 0.0,
#     'seguros_open': 12.0,
#     'seguros_related': 22.0,
#     'tecban': 2.0}},
#   'captacoes': {'spread': {'cdb': 0.46,
#     'contamax': 12.66,
#     'dav': 6.29,
#     'demais': 16.21,
#     'letras': 0.74,
#     'poupanca': 1.65},
#    'carteira': {'cdb': 81.0,
#     'contamax': 218.0,
#     'dav': 75.0,
#     'demais': 12.0,
#     'letras': 7.0,
#     'poupanca': 1145.0},
#    'margem': {'cdb': 0.4,
#     'contamax': 27.6,
#     'dav': 4.7,
#     'demais': 0.7,
#     'letras': 0.1,
#     'poupanca': 18.9}},
#   'cascada': {'cascada': {'bai': 333.0,
#     'bdi': 176.0,
#     'demais_ativos': -1.0,
#     'eficiencia': 35.7,
#     'impostos': -157.0,
#     'mob': 1269.0,
#     'mol': 857.0,
#     'oryp': -70.0,
#     'pdd': -412.0,
#     'rorwa': 15.4,
#     'rwa': 1143.07,
#     'taxa_impositiva': 47.1,
#     'total_gastos': -453.0},
#    'ppto': {'ppto_bai': 733.0,
#     'ppto_bdi': 456.0,
#     'ppto_demais_ativos': -8.0,
#     'ppto_impostos': -277.0,
#     'ppto_mob': 1666.0,
#     'ppto_mol': 1276.0,
#     'ppto_oryp': -95.0,
#     'ppto_pdd': -390.0,
#     'ppto_total_gastos': -440.0},
#    'atingimento': {'atingimento_bai': 45.43,
#     'atingimento_bdi': 38.6,
#     'atingimento_demais_ativos': 12.5,
#     'atingimento_impostos': 56.68,
#     'atingimento_mob': 76.17,
#     'atingimento_mol': 67.16,
#     'atingimento_oryp': 73.68,
#     'atingimento_pdd': 105.64,
#     'atingimento_total_gastos': 102.95}}},
#  'select': {'credito': {'carteira': {'agro': 7002.0,
#     'autos': 3906.0,
#     'cartoes': 27769.0,
#     'cheque_especial': 2610.0,
#     'comex': 2111.0,
#     'consignado': 19940.0,
#     'cp': 6817.0,
#     'demais': 18710.0,
#     'hipotecas': 53263.0},
#    'spread': {'agro': 5.82,
#     'autos': 6.86,
#     'cartoes': 9.76,
#     'cheque_especial': 79.92,
#     'comex': 2.61,
#     'consignado': 8.15,
#     'cp': 22.56,
#     'demais': 131.20000000000002,
#     'hipotecas': 1.22},
#    'provisao': {'agro': -210.0,
#     'autos': -200.0,
#     'cartoes': -1585.0,
#     'cheque_especial': -327.0,
#     'comex': -4.0,
#     'consignado': -552.0,
#     'cp': -2269.0,
#     'demais': -78.0,
#     'hipotecas': -208.0},
#    'margem': {'agro': 407.5,
#     'autos': 268.0,
#     'cartoes': 2710.3,
#     'cheque_especial': 2085.9,
#     'comex': 55.1,
#     'consignado': 1625.1,
#     'cp': 1537.9,
#     'demais': 215.5,
#     'hipotecas': 649.8},
#    'rwa': {'agro': 3944.0,
#     'autos': 2766.0,
#     'cartoes': 10801.0,
#     'cheque_especial': 1594.0,
#     'comex': 1175.0,
#     'consignado': 11694.0,
#     'cp': 2443.0,
#     'demais': 7542.0,
#     'hipotecas': 16390.0}},
#   'comissoes': {'comissoes': {'aaa': 62.0,
#     'capitalizacao': 1439.0,
#     'cartoes': 2153.0,
#     'demais': 4789.0,
#     'esfera': 373.0,
#     'seguros_open': 781.0,
#     'seguros_related': 661.0,
#     'tecban': 12.0}},
#   'captacoes': {'spread': {'captacoes_comex': 5.65,
#     'cdb': 0.77,
#     'contamax': 12.67,
#     'dav': 6.27,
#     'demais': 0.21,
#     'letras': 0.7,
#     'poupanca': 1.66},
#    'carteira': {'captacoes_comex': 118.0,
#     'cdb': 68322.0,
#     'contamax': 19871.0,
#     'dav': 498.0,
#     'demais': 30864.0,
#     'letras': 20373.0,
#     'poupanca': 34844.0},
#    'margem': {'captacoes_comex': 6.7,
#     'cdb': 526.1,
#     'contamax': 2517.7,
#     'dav': 31.2,
#     'demais': 32.4,
#     'letras': 142.6,
#     'poupanca': 578.4}},
#   'cascada': {'cascada': {'bai': 4504.0,
#     'bdi': 2328.0,
#     'demais_ativos': -74.0,
#     'eficiencia': 39.6,
#     'impostos': -2176.0,
#     'mob': 18966.0,
#     'mol': 12919.0,
#     'oryp': -834.0,
#     'pdd': -6047.0,
#     'rorwa': 3.94,
#     'rwa': 59090.22,
#     'taxa_impositiva': 48.3,
#     'total_gastos': -7507.0},
#    'ppto': {'ppto_bai': 4680.0,
#     'ppto_bdi': 2590.0,
#     'ppto_demais_ativos': -163.0,
#     'ppto_impostos': -2090.0,
#     'ppto_mob': 18511.0,
#     'ppto_mol': 12669.0,
#     'ppto_oryp': -479.0,
#     'ppto_pdd': -5841.0,
#     'ppto_total_gastos': -7347.0},
#    'atingimento': {'atingimento_bai': 96.24,
#     'atingimento_bdi': 89.88,
#     'atingimento_demais_ativos': 45.4,
#     'atingimento_impostos': 104.11,
#     'atingimento_mob': 102.46,
#     'atingimento_mol': 101.97,
#     'atingimento_oryp': 174.11,
#     'atingimento_pdd': 103.53,
#     'atingimento_total_gastos': 102.18}}},
#  'pj': {'credito': {'carteira': {'agro': 1169.0,
#     'autos': 4791.0,
#     'capital_de_giro': 30441.0,
#     'cartoes': 4088.0,
#     'comex': 15184.0,
#     'confirming': 985.0,
#     'conta_garantida': 3113.0,
#     'demais': 23184.0,
#     'hipotecas': 2377.0,
#     'internegocios': 834.0},
#    'spread': {'agro': 4.89,
#     'autos': 5.41,
#     'capital_de_giro': 9.36,
#     'cartoes': 14.89,
#     'comex': 3.17,
#     'confirming': 3.56,
#     'conta_garantida': 16.77,
#     'demais': 180.5,
#     'hipotecas': 2.32,
#     'internegocios': 1.14},
#    'provisao': {'agro': -4.0,
#     'autos': -273.0,
#     'capital_de_giro': -1116.0,
#     'cartoes': -605.0,
#     'comex': -41.0,
#     'confirming': -11.0,
#     'conta_garantida': -154.0,
#     'demais': -806.0,
#     'hipotecas': -16.0,
#     'internegocios': 0.0},
#    'margem': {'agro': 57.2,
#     'autos': 259.2,
#     'capital_de_giro': 2849.3,
#     'cartoes': 608.7,
#     'comex': 481.3,
#     'confirming': 35.1,
#     'conta_garantida': 522.1,
#     'demais': 4248.9,
#     'hipotecas': 55.1,
#     'internegocios': 9.5},
#    'rwa': {'agro': 758.0,
#     'autos': 3617.0,
#     'capital_de_giro': 20078.0,
#     'cartoes': 2057.0,
#     'comex': 10603.0,
#     'confirming': 930.0,
#     'conta_garantida': 1942.0,
#     'demais': 5087.0,
#     'hipotecas': 1832.0,
#     'internegocios': 87.0}},
#   'comissoes': {'comissoes': {'adquirencia': 17.0,
#     'capitalizacao': 28.0,
#     'cartoes': 576.0,
#     'cash': 12.0,
#     'demais': 2661.0,
#     'esfera': 431.0,
#     'fx': 100.0,
#     'seguros_open': 576.0,
#     'seguros_related': 254.0,
#     'tecban': 82.0}},
#   'captacoes': {'spread': {'captacoes_comex': 3.81,
#     'cdb': 0.53,
#     'contamax': 12.84,
#     'dav': 6.09,
#     'demais': 2.26,
#     'letras': 5.16,
#     'poupanca': 1.68,
#     'time_deposit': 0.55},
#    'carteira': {'captacoes_comex': 83.0,
#     'cdb': 52686.0,
#     'contamax': 27870.0,
#     'dav': 7252.0,
#     'demais': 18436.0,
#     'letras': 2123.0,
#     'poupanca': 751.0,
#     'time_deposit': 68.0},
#    'margem': {'captacoes_comex': 3.2,
#     'cdb': 279.2,
#     'contamax': 3578.5,
#     'dav': 441.6,
#     'demais': 208.3,
#     'letras': 109.5,
#     'poupanca': 12.6,
#     'time_deposit': 0.4}},
#   'cascada': {'cascada': {'bai': 7859.0,
#     'bdi': 4675.0,
#     'demais_ativos': -11.0,
#     'eficiencia': 30.7,
#     'impostos': -3184.0,
#     'mob': 21408.0,
#     'mol': 15508.0,
#     'oryp': -1073.0,
#     'pdd': -5900.0,
#     'rorwa': 5.82,
#     'rwa': 80276.0,
#     'taxa_impositiva': 40.5,
#     'total_gastos': -6565.0},
#    'ppto': {'ppto_bai': 8253.0,
#     'ppto_bdi': 5040.0,
#     'ppto_demais_ativos': -220.0,
#     'ppto_impostos': -3213.0,
#     'ppto_mob': 21926.0,
#     'ppto_mol': 16014.0,
#     'ppto_oryp': -1093.0,
#     'ppto_pdd': -5911.0,
#     'ppto_total_gastos': -6448.0},
#    'atingimento': {'atingimento_bai': 95.23,
#     'atingimento_bdi': 92.76,
#     'atingimento_demais_ativos': 5.0,
#     'atingimento_impostos': 99.1,
#     'atingimento_mob': 97.64,
#     'atingimento_mol': 96.84,
#     'atingimento_oryp': 98.17,
#     'atingimento_pdd': 99.81,
#     'atingimento_total_gastos': 101.81}}},
#  'corporate': {'credito': {'carteira': {'agro': 12673.0,
#     'autos': 1621.0,
#     'capital_de_giro': 2212.0,
#     'comex': 49167.0,
#     'confirming': 5140.0,
#     'conta_garantida': 804.0,
#     'demais': 39558.0,
#     'hipotecas': 1318.0,
#     'internegocios': 3598.0},
#    'spread': {'agro': 2.32,
#     'autos': 3.38,
#     'capital_de_giro': 3.6,
#     'comex': 2.15,
#     'confirming': 4.07,
#     'conta_garantida': 5.77,
#     'demais': 193.34,
#     'hipotecas': 2.09,
#     'internegocios': 1.61},
#    'provisao': {'agro': -8.0,
#     'autos': 0.0,
#     'capital_de_giro': -19.0,
#     'comex': -4.0,
#     'confirming': -21.0,
#     'conta_garantida': -2.0,
#     'demais': -141.0,
#     'hipotecas': -5.0,
#     'internegocios': -4.0},
#    'margem': {'agro': 294.0,
#     'autos': 54.8,
#     'capital_de_giro': 79.6,
#     'comex': 1057.1,
#     'confirming': 209.2,
#     'conta_garantida': 46.4,
#     'demais': 304.2,
#     'hipotecas': 27.5,
#     'internegocios': 57.9},
#    'rwa': {'agro': 9186.0,
#     'autos': 1321.0,
#     'capital_de_giro': 3330.0,
#     'comex': 33518.0,
#     'confirming': 3442.0,
#     'conta_garantida': 1753.0,
#     'demais': 5319.0,
#     'hipotecas': 1307.0,
#     'internegocios': 2155.0}},
#   'comissoes': {'comissoes': {'adquirencia': 164.0,
#     'capitalizacao': 10.0,
#     'cartoes': 39.0,
#     'cash': 0.0,
#     'demais': 1478.0,
#     'fianca': 498.0,
#     'fx': 48.0,
#     'mercado_de_capitais': 264.0,
#     'seguros_open': 39.0,
#     'seguros_related': 16.0}},
#   'captacoes': {'spread': {'captacoes_comex': 2.62,
#     'cdb': 0.39,
#     'contamax': 12.94,
#     'dav': 6.11,
#     'demais': 4.38,
#     'letras': 2.49,
#     'time_deposit': 0.79},
#    'carteira': {'captacoes_comex': 2071.0,
#     'cdb': 41079.0,
#     'contamax': 6038.0,
#     'dav': 3103.0,
#     'demais': 3526.0,
#     'letras': 7197.0,
#     'time_deposit': 2829.0},
#    'margem': {'captacoes_comex': 54.3,
#     'cdb': 160.2,
#     'contamax': 781.3,
#     'dav': 189.6,
#     'demais': 67.10000000000001,
#     'letras': 179.2,
#     'time_deposit': 22.3}},
#   'cascada': {'cascada': {'bai': 5035.0,
#     'bdi': 3315.0,
#     'demais_ativos': 0.0,
#     'eficiencia': 11.6,
#     'impostos': -1720.0,
#     'mob': 6376.0,
#     'mol': 5797.0,
#     'oryp': -20.0,
#     'pdd': -579.0,
#     'rorwa': 3.33,
#     'rwa': 99616.0,
#     'taxa_impositiva': 34.2,
#     'total_gastos': -742.0},
#    'ppto': {'ppto_bai': 4987.0,
#     'ppto_bdi': 3300.0,
#     'ppto_demais_ativos': 0.0,
#     'ppto_impostos': -1687.0,
#     'ppto_mob': 6302.0,
#     'ppto_mol': 5809.0,
#     'ppto_oryp': -19.0,
#     'ppto_pdd': -493.0,
#     'ppto_total_gastos': -803.0},
#    'atingimento': {'atingimento_bai': 100.96,
#     'atingimento_bdi': 100.45,
#     'atingimento_demais_ativos': 0.0,
#     'atingimento_impostos': 101.96,
#     'atingimento_mob': 101.17,
#     'atingimento_mol': 99.79,
#     'atingimento_oryp': 105.26,
#     'atingimento_pdd': 117.44,
#     'atingimento_total_gastos': 92.4}}},
#  'scib': {'credito': {'carteira': {'agro': 2352.0,
#     'autos': 264.0,
#     'capital_de_giro': 4073.0,
#     'cartoes': 164.0,
#     'comex': 32579.0,
#     'confirming': 16530.0,
#     'demais': 103476.0,
#     'hipotecas': 345.0,
#     'internegocios': 15828.0},
#    'spread': {'agro': 1.64,
#     'autos': 4.09,
#     'capital_de_giro': 2.08,
#     'cartoes': 1.99,
#     'comex': 1.41,
#     'confirming': 1.82,
#     'demais': 202.79999999999998,
#     'hipotecas': 2.39,
#     'internegocios': 1.0},
#    'provisao': {'agro': -2.0,
#     'autos': 0.0,
#     'capital_de_giro': -340.0,
#     'cartoes': 0.0,
#     'comex': -6.0,
#     'confirming': -897.0,
#     'demais': -956.0,
#     'hipotecas': 0.0,
#     'internegocios': -9.0},
#    'margem': {'agro': 38.6,
#     'autos': 10.8,
#     'capital_de_giro': 84.7,
#     'cartoes': 3.3,
#     'comex': 459.4,
#     'confirming': 300.8,
#     'demais': 105.9,
#     'hipotecas': 8.2,
#     'internegocios': 158.3},
#    'rwa': {'agro': 1029.0,
#     'autos': 238.0,
#     'capital_de_giro': 2237.0,
#     'cartoes': 88.0,
#     'comex': 12667.0,
#     'confirming': 3804.0,
#     'demais': 3872.0,
#     'hipotecas': 262.0,
#     'internegocios': 12836.0}},
#   'comissoes': {'comissoes': {'cash': 0.0,
#     'comex': 191.0,
#     'corretagem': 0.0,
#     'demais': 633.0,
#     'fianca': 0.0,
#     'fx': 0.0,
#     'mercado_de_capitais': 60.0}},
#   'captacoes': {'spread': {'captacoes_comex': 0.27,
#     'cdb': 0.3,
#     'contamax': 8.56,
#     'dav': 7.39,
#     'demais': 21.78,
#     'letras': 2.84,
#     'lf': 0.0,
#     'time_deposit': 0.36},
#    'carteira': {'captacoes_comex': 115973.0,
#     'cdb': 91061.0,
#     'contamax': 5534.0,
#     'dav': 4592.0,
#     'demais': 1658.0,
#     'letras': 3778.0,
#     'lf': 1276.0,
#     'time_deposit': 14084.0},
#    'margem': {'captacoes_comex': 313.1,
#     'cdb': 273.2,
#     'contamax': 473.7,
#     'dav': 339.3,
#     'demais': 29.2,
#     'letras': 107.3,
#     'lf': 0.0,
#     'time_deposit': 50.7}},
#   'cascada': {'cascada': {'bai': 6681.0,
#     'bdi': 4518.0,
#     'demais_ativos': 0.0,
#     'eficiencia': 26.2,
#     'impostos': -2163.0,
#     'mob': 9229.0,
#     'mol': 9120.0,
#     'oryp': -19.0,
#     'pdd': -109.0,
#     'rorwa': 3.68,
#     'rwa': 122660.0,
#     'taxa_impositiva': 32.4,
#     'total_gastos': -2420.0},
#    'ppto': {'ppto_bai': 6669.0,
#     'ppto_bdi': 4842.0,
#     'ppto_demais_ativos': 0.0,
#     'ppto_impostos': -2232.0,
#     'ppto_mob': 9113.0,
#     'ppto_mol': 8998.0,
#     'ppto_oryp': -21.0,
#     'ppto_pdd': -115.0,
#     'ppto_total_gastos': -2308.0},
#    'atingimento': {'atingimento_bai': 100.18,
#     'atingimento_bdi': 93.31,
#     'atingimento_demais_ativos': 0.0,
#     'atingimento_impostos': 96.91,
#     'atingimento_mob': 101.27,
#     'atingimento_mol': 101.36,
#     'atingimento_oryp': 90.48,
#     'atingimento_pdd': 94.78,
#     'atingimento_total_gastos': 104.85}}},
#  'private': {'credito': {'carteira': {'agro': 68.0,
#     'autos': 558.0,
#     'capital_de_giro': 39.0,
#     'cartoes': 486.0,
#     'comex': 2956.0,
#     'cp': 57.0,
#     'demais': 1550.0,
#     'hipotecas': 1863.0,
#     'internegocios': 471.0},
#    'spread': {'agro': 3.35,
#     'autos': 2.33,
#     'capital_de_giro': 0.99,
#     'cartoes': 2.15,
#     'comex': 1.53,
#     'cp': 3.71,
#     'demais': 63.11,
#     'hipotecas': 1.16,
#     'internegocios': 1.88},
#    'provisao': {'agro': 0.0,
#     'autos': 0.0,
#     'capital_de_giro': 0.0,
#     'cartoes': -2.0,
#     'comex': -1.0,
#     'cp': 0.0,
#     'demais': -2.0,
#     'hipotecas': 0.0,
#     'internegocios': 0.0},
#    'margem': {'agro': 2.3,
#     'autos': 13.0,
#     'capital_de_giro': 0.4,
#     'cartoes': 10.4,
#     'comex': 45.2,
#     'cp': 2.1,
#     'demais': 5.7,
#     'hipotecas': 21.6,
#     'internegocios': 8.9},
#    'rwa': {'agro': 30.0,
#     'autos': 520.0,
#     'capital_de_giro': 6.0,
#     'cartoes': 131.0,
#     'comex': 1258.0,
#     'cp': 14.0,
#     'demais': 34.0,
#     'hipotecas': 703.0,
#     'internegocios': 0.0}},
#   'comissoes': {'comissoes': {'cartoes': 32.0,
#     'comex': 0.0,
#     'demais': 208.0,
#     'esfera': 0.0,
#     'fundos': 24.0,
#     'fx': 526.0,
#     'mercado_de_capitais': 0.0,
#     'previdencia': 0.0}},
#   'captacoes': {'spread': {'captacoes_comex': 0.02,
#     'cdb': 0.46,
#     'coe': 0.0,
#     'contamax': 12.43,
#     'dav': 5.5,
#     'demais': 1.48,
#     'letras': 0.37},
#    'carteira': {'captacoes_comex': 1539.0,
#     'cdb': 17431.0,
#     'coe': 947.0,
#     'contamax': 1106.0,
#     'dav': 129.0,
#     'demais': 1167.0,
#     'letras': 54189.0},
#    'margem': {'captacoes_comex': 0.3,
#     'cdb': 80.2,
#     'coe': 0.0,
#     'contamax': 137.5,
#     'dav': 7.1,
#     'demais': 1.5,
#     'letras': 200.5}},
#   'cascada': {'cascada': {'bai': 604.0,
#     'bdi': 388.0,
#     'demais_ativos': 0.0,
#     'eficiencia': 46.0,
#     'impostos': -216.0,
#     'mob': 1130.0,
#     'mol': 1126.0,
#     'oryp': -2.0,
#     'pdd': -4.0,
#     'rorwa': 5.63,
#     'rwa': 6890.0,
#     'taxa_impositiva': 35.8,
#     'total_gastos': -520.0},
#    'ppto': {'ppto_bai': 607.0,
#     'ppto_bdi': 392.0,
#     'ppto_demais_ativos': 0.0,
#     'ppto_impostos': -215.0,
#     'ppto_mob': 1124.0,
#     'ppto_mol': 1109.0,
#     'ppto_oryp': -2.0,
#     'ppto_pdd': -15.0,
#     'ppto_total_gastos': -500.0},
#    'atingimento': {'atingimento_bai': 99.51,
#     'atingimento_bdi': 98.98,
#     'atingimento_demais_ativos': 0.0,
#     'atingimento_impostos': 100.47,
#     'atingimento_mob': 100.53,
#     'atingimento_mol': 101.53,
#     'atingimento_oryp': 100.0,
#     'atingimento_pdd': 26.67,
#     'atingimento_total_gastos': 104.0}}},
#  'consumer': {'credito': {'carteira': {'autos': 64583.0,
#     'cp': 877.0,
#     'demais': 3874.0},
#    'spread': {'autos': 7.81, 'cp': 21.11, 'demais': 8.23},
#    'provisao': {'autos': -3891.0, 'cp': 0.0, 'demais': 0.0},
#    'margem': {'autos': 5043.9, 'cp': 185.1, 'demais': 314.7},
#    'rwa': {'autos': 49758.0, 'cp': 796.0, 'demais': 1234.0}},
#   'comissoes': {'comissoes': {'demais': 133.0,
#     'seguros_open': 0.0,
#     'seguros_related': 0.0,
#     'tarifas_de_credito': 0.0}},
#   'captacoes': {'spread': {'demais': 0.0},
#    'carteira': {'demais': 0.0},
#    'margem': {'demais': 0.0}},
#   'cascada': {'cascada': {'bai': 2012.0,
#     'bdi': 1209.0,
#     'demais_ativos': 0.0,
#     'eficiencia': 15.9,
#     'impostos': -803.0,
#     'mob': 7218.0,
#     'mol': 3467.0,
#     'oryp': -307.0,
#     'pdd': -3751.0,
#     'rorwa': 1.72,
#     'rwa': 70232.0,
#     'taxa_impositiva': 39.9,
#     'total_gastos': -1148.0},
#    'ppto': {'ppto_bai': 2012.0,
#     'ppto_bdi': 1161.0,
#     'ppto_demais_ativos': 0.0,
#     'ppto_impostos': -851.0,
#     'ppto_mob': 7268.0,
#     'ppto_mol': 3457.0,
#     'ppto_oryp': -297.0,
#     'ppto_pdd': -3811.0,
#     'ppto_total_gastos': -1148.0},
#    'atingimento': {'atingimento_bai': 100.0,
#     'atingimento_bdi': 104.13,
#     'atingimento_demais_ativos': 0.0,
#     'atingimento_impostos': 94.36,
#     'atingimento_mob': 99.31,
#     'atingimento_mol': 100.29,
#     'atingimento_oryp': 103.37,
#     'atingimento_pdd': 98.43,
#     'atingimento_total_gastos': 100.0}}},
#  'total': {'cascada': {'cascada': {'bai': 25843.0,
#     'bdi': 15236.0,
#     'demais_ativos': -314.0,
#     'eficiencia': 31.9,
#     'impostos': -10607.0,
#     'mob': 81922.0,
#     'mol': 55393.0,
#     'oryp': -3107.0,
#     'pdd': -26529.0,
#     'rorwa': 2.54,
#     'rwa': 600644.0,
#     'taxa_impositiva': 41.0,
#     'total_gastos': -26129.0},
#    'ppto': {'ppto_bai': 27120.0,
#     'ppto_bdi': 16480.0,
#     'ppto_demais_ativos': -548.0,
#     'ppto_impostos': -10640.0,
#     'ppto_mob': 82847.0,
#     'ppto_mol': 56498.0,
#     'ppto_oryp': -3130.0,
#     'ppto_pdd': -26349.0,
#     'ppto_total_gastos': -25700.0},
#    'atingimento': {'atingimento_bai': 95.29,
#     'atingimento_bdi': 92.45,
#     'atingimento_demais_ativos': 57.3,
#     'atingimento_impostos': 99.69,
#     'atingimento_mob': 98.88,
#     'atingimento_mol': 98.04,
#     'atingimento_oryp': 99.27,
#     'atingimento_pdd': 100.68,
#     'atingimento_total_gastos': 101.67}}}}

# %%
# Cálculo do spread correto
for segmento in segmentos:
    for topico in dict_indicadores[segmento].keys():
        if topico in ["credito", "captacoes"]:
            for abertura in dict_indicadores[segmento][topico]["spread"]:
                try:
                    dict_indicadores[segmento][topico]["spread"][abertura] = round(dict_indicadores[segmento][topico]["margem"][abertura] / dict_indicadores[segmento][topico]["carteira"][abertura] * 100, 2)
                except:
                    dict_indicadores[segmento][topico]["spread"][abertura] = 0

# %%
dict_indicadores
# Out:
# {'especial': {'credito': {'carteira': {'autos': 4970.0,
#     'cartoes': 20157.0,
#     'cheque_especial': 1747.0,
#     'consignado': 38458.0,
#     'cp': 6964.0,
#     'demais': 67.0,
#     'hipotecas': 11632.0},
#    'spread': {'autos': 9.37,
#     'cartoes': 17.02,
#     'cheque_especial': 89.48,
#     'consignado': 8.57,
#     'cp': 22.33,
#     'demais': 26.87,
#     'hipotecas': 1.47},
#    'provisao': {'autos': -380.0,
#     'cartoes': -3317.0,
#     'cheque_especial': -477.0,
#     'consignado': -1957.0,
#     'cp': -2917.0,
#     'demais': -22.0,
#     'hipotecas': -68.0},
#    'margem': {'autos': 465.7,
#     'cartoes': 3430.7,
#     'cheque_especial': 1563.2,
#     'consignado': 3295.9,
#     'cp': 1555.1,
#     'demais': 18.0,
#     'hipotecas': 171.0},
#    'rwa': {'autos': 3519.0,
#     'cartoes': 7841.0,
#     'cheque_especial': 1067.0,
#     'consignado': 22553.0,
#     'cp': 2496.0,
#     'demais': 28.0,
#     'hipotecas': 3579.0}},
#   'comissoes': {'comissoes': {'capitalizacao': 448.0,
#     'cartoes': 1654.0,
#     'demais': 1822.0,
#     'esfera': 33.0,
#     'fidelizacao_inss': 266.0,
#     'seguros_open': 597.0,
#     'seguros_related': 491.0,
#     'tecban': 0.0}},
#   'captacoes': {'spread': {'cdb': 0.54,
#     'contamax': 12.65,
#     'dav': 6.29,
#     'demais': 3.2,
#     'letras': 0.71,
#     'poupanca': 1.67},
#    'carteira': {'cdb': 5517.0,
#     'contamax': 11509.0,
#     'dav': 706.0,
#     'demais': 859.0,
#     'letras': 800.0,
#     'poupanca': 18838.0},
#    'margem': {'cdb': 29.8,
#     'contamax': 1455.9,
#     'dav': 44.4,
#     'demais': 27.5,
#     'letras': 5.7,
#     'poupanca': 314.6}},
#   'cascada': {'cascada': {'bai': -1848.0,
#     'bdi': -1735.0,
#     'demais_ativos': -185.0,
#     'eficiencia': 39.0,
#     'impostos': 113.0,
#     'mob': 14768.0,
#     'mol': 5070.0,
#     'oryp': -972.0,
#     'pdd': -9698.0,
#     'rorwa': -4.2,
#     'rwa': 41286.86,
#     'taxa_impositiva': 6.1,
#     'total_gastos': -5761.0},
#    'ppto': {'ppto_bai': 1579.0,
#     'ppto_bdi': 1638.0,
#     'ppto_demais_ativos': -144.0,
#     'ppto_impostos': -59.0,
#     'ppto_mob': 15351.0,
#     'ppto_mol': 5580.0,
#     'ppto_oryp': -1298.0,
#     'ppto_pdd': -9771.0,
#     'ppto_total_gastos': -5717.0},
#    'atingimento': {'atingimento_bai': -117.04,
#     'atingimento_bdi': -105.92,
#     'atingimento_demais_ativos': 128.47,
#     'atingimento_impostos': -191.53,
#     'atingimento_mob': 96.2,
#     'atingimento_mol': 90.86,
#     'atingimento_oryp': 74.88,
#     'atingimento_pdd': 99.25,
#     'atingimento_total_gastos': 100.77}}},
#  'prospera': {'credito': {'carteira': {'autos': 184.0,
#     'cartoes': 182.0,
#     'cheque_especial': 18.0,
#     'consignado': 1494.0,
#     'cp': 44.0,
#     'demais': 0.0,
#     'hipotecas': 107.0,
#     'microcredito': 2719.0},
#    'spread': {'autos': 9.24,
#     'cartoes': 17.75,
#     'cheque_especial': 92.78,
#     'consignado': 6.89,
#     'cp': 22.73,
#     'demais': 0,
#     'hipotecas': 1.5,
#     'microcredito': 36.11},
#    'provisao': {'autos': -28.0,
#     'cartoes': -181.0,
#     'cheque_especial': -10.0,
#     'consignado': -96.0,
#     'cp': -34.0,
#     'demais': 0.0,
#     'hipotecas': 0.0,
#     'microcredito': -213.0},
#    'margem': {'autos': 17.0,
#     'cartoes': 32.3,
#     'cheque_especial': 16.7,
#     'consignado': 102.9,
#     'cp': 10.0,
#     'demais': 0.0,
#     'hipotecas': 1.6,
#     'microcredito': 981.8},
#    'rwa': {'autos': 130.0,
#     'cartoes': 71.0,
#     'cheque_especial': 11.0,
#     'consignado': 876.0,
#     'cp': 16.0,
#     'demais': 0.0,
#     'hipotecas': 33.0,
#     'microcredito': 1411.0}},
#   'comissoes': {'comissoes': {'capitalizacao': 12.0,
#     'cartoes': 76.0,
#     'demais': 37.0,
#     'esfera': 0.0,
#     'fidelizacao_inss': 0.0,
#     'seguros_open': 12.0,
#     'seguros_related': 22.0,
#     'tecban': 2.0}},
#   'captacoes': {'spread': {'cdb': 0.49,
#     'contamax': 12.66,
#     'dav': 6.27,
#     'demais': 5.83,
#     'letras': 1.43,
#     'poupanca': 1.65},
#    'carteira': {'cdb': 81.0,
#     'contamax': 218.0,
#     'dav': 75.0,
#     'demais': 12.0,
#     'letras': 7.0,
#     'poupanca': 1145.0},
#    'margem': {'cdb': 0.4,
#     'contamax': 27.6,
#     'dav': 4.7,
#     'demais': 0.7,
#     'letras': 0.1,
#     'poupanca': 18.9}},
#   'cascada': {'cascada': {'bai': 333.0,
#     'bdi': 176.0,
#     'demais_ativos': -1.0,
#     'eficiencia': 35.7,
#     'impostos': -157.0,
#     'mob': 1269.0,
#     'mol': 857.0,
#     'oryp': -70.0,
#     'pdd': -412.0,
#     'rorwa': 15.4,
#     'rwa': 1143.07,
#     'taxa_impositiva': 47.1,
#     'total_gastos': -453.0},
#    'ppto': {'ppto_bai': 733.0,
#     'ppto_bdi': 456.0,
#     'ppto_demais_ativos': -8.0,
#     'ppto_impostos': -277.0,
#     'ppto_mob': 1666.0,
#     'ppto_mol': 1276.0,
#     'ppto_oryp': -95.0,
#     'ppto_pdd': -390.0,
#     'ppto_total_gastos': -440.0},
#    'atingimento': {'atingimento_bai': 45.43,
#     'atingimento_bdi': 38.6,
#     'atingimento_demais_ativos': 12.5,
#     'atingimento_impostos': 56.68,
#     'atingimento_mob': 76.17,
#     'atingimento_mol': 67.16,
#     'atingimento_oryp': 73.68,
#     'atingimento_pdd': 105.64,
#     'atingimento_total_gastos': 102.95}}},
#  'select': {'credito': {'carteira': {'agro': 7002.0,
#     'autos': 3906.0,
#     'cartoes': 27769.0,
#     'cheque_especial': 2610.0,
#     'comex': 2111.0,
#     'consignado': 19940.0,
#     'cp': 6817.0,
#     'demais': 18710.0,
#     'hipotecas': 53263.0},
#    'spread': {'agro': 5.82,
#     'autos': 6.86,
#     'cartoes': 9.76,
#     'cheque_especial': 79.92,
#     'comex': 2.61,
#     'consignado': 8.15,
#     'cp': 22.56,
#     'demais': 1.15,
#     'hipotecas': 1.22},
#    'provisao': {'agro': -210.0,
#     'autos': -200.0,
#     'cartoes': -1585.0,
#     'cheque_especial': -327.0,
#     'comex': -4.0,
#     'consignado': -552.0,
#     'cp': -2269.0,
#     'demais': -78.0,
#     'hipotecas': -208.0},
#    'margem': {'agro': 407.5,
#     'autos': 268.0,
#     'cartoes': 2710.3,
#     'cheque_especial': 2085.9,
#     'comex': 55.1,
#     'consignado': 1625.1,
#     'cp': 1537.9,
#     'demais': 215.5,
#     'hipotecas': 649.8},
#    'rwa': {'agro': 3944.0,
#     'autos': 2766.0,
#     'cartoes': 10801.0,
#     'cheque_especial': 1594.0,
#     'comex': 1175.0,
#     'consignado': 11694.0,
#     'cp': 2443.0,
#     'demais': 7542.0,
#     'hipotecas': 16390.0}},
#   'comissoes': {'comissoes': {'aaa': 62.0,
#     'capitalizacao': 1439.0,
#     'cartoes': 2153.0,
#     'demais': 4789.0,
#     'esfera': 373.0,
#     'seguros_open': 781.0,
#     'seguros_related': 661.0,
#     'tecban': 12.0}},
#   'captacoes': {'spread': {'captacoes_comex': 5.68,
#     'cdb': 0.77,
#     'contamax': 12.67,
#     'dav': 6.27,
#     'demais': 0.1,
#     'letras': 0.7,
#     'poupanca': 1.66},
#    'carteira': {'captacoes_comex': 118.0,
#     'cdb': 68322.0,
#     'contamax': 19871.0,
#     'dav': 498.0,
#     'demais': 30864.0,
#     'letras': 20373.0,
#     'poupanca': 34844.0},
#    'margem': {'captacoes_comex': 6.7,
#     'cdb': 526.1,
#     'contamax': 2517.7,
#     'dav': 31.2,
#     'demais': 32.4,
#     'letras': 142.6,
#     'poupanca': 578.4}},
#   'cascada': {'cascada': {'bai': 4504.0,
#     'bdi': 2328.0,
#     'demais_ativos': -74.0,
#     'eficiencia': 39.6,
#     'impostos': -2176.0,
#     'mob': 18966.0,
#     'mol': 12919.0,
#     'oryp': -834.0,
#     'pdd': -6047.0,
#     'rorwa': 3.94,
#     'rwa': 59090.22,
#     'taxa_impositiva': 48.3,
#     'total_gastos': -7507.0},
#    'ppto': {'ppto_bai': 4680.0,
#     'ppto_bdi': 2590.0,
#     'ppto_demais_ativos': -163.0,
#     'ppto_impostos': -2090.0,
#     'ppto_mob': 18511.0,
#     'ppto_mol': 12669.0,
#     'ppto_oryp': -479.0,
#     'ppto_pdd': -5841.0,
#     'ppto_total_gastos': -7347.0},
#    'atingimento': {'atingimento_bai': 96.24,
#     'atingimento_bdi': 89.88,
#     'atingimento_demais_ativos': 45.4,
#     'atingimento_impostos': 104.11,
#     'atingimento_mob': 102.46,
#     'atingimento_mol': 101.97,
#     'atingimento_oryp': 174.11,
#     'atingimento_pdd': 103.53,
#     'atingimento_total_gastos': 102.18}}},
#  'pj': {'credito': {'carteira': {'agro': 1169.0,
#     'autos': 4791.0,
#     'capital_de_giro': 30441.0,
#     'cartoes': 4088.0,
#     'comex': 15184.0,
#     'confirming': 985.0,
#     'conta_garantida': 3113.0,
#     'demais': 23184.0,
#     'hipotecas': 2377.0,
#     'internegocios': 834.0},
#    'spread': {'agro': 4.89,
#     'autos': 5.41,
#     'capital_de_giro': 9.36,
#     'cartoes': 14.89,
#     'comex': 3.17,
#     'confirming': 3.56,
#     'conta_garantida': 16.77,
#     'demais': 18.33,
#     'hipotecas': 2.32,
#     'internegocios': 1.14},
#    'provisao': {'agro': -4.0,
#     'autos': -273.0,
#     'capital_de_giro': -1116.0,
#     'cartoes': -605.0,
#     'comex': -41.0,
#     'confirming': -11.0,
#     'conta_garantida': -154.0,
#     'demais': -806.0,
#     'hipotecas': -16.0,
#     'internegocios': 0.0},
#    'margem': {'agro': 57.2,
#     'autos': 259.2,
#     'capital_de_giro': 2849.3,
#     'cartoes': 608.7,
#     'comex': 481.3,
#     'confirming': 35.1,
#     'conta_garantida': 522.1,
#     'demais': 4248.9,
#     'hipotecas': 55.1,
#     'internegocios': 9.5},
#    'rwa': {'agro': 758.0,
#     'autos': 3617.0,
#     'capital_de_giro': 20078.0,
#     'cartoes': 2057.0,
#     'comex': 10603.0,
#     'confirming': 930.0,
#     'conta_garantida': 1942.0,
#     'demais': 5087.0,
#     'hipotecas': 1832.0,
#     'internegocios': 87.0}},
#   'comissoes': {'comissoes': {'adquirencia': 17.0,
#     'capitalizacao': 28.0,
#     'cartoes': 576.0,
#     'cash': 12.0,
#     'demais': 2661.0,
#     'esfera': 431.0,
#     'fx': 100.0,
#     'seguros_open': 576.0,
#     'seguros_related': 254.0,
#     'tecban': 82.0}},
#   'captacoes': {'spread': {'captacoes_comex': 3.86,
#     'cdb': 0.53,
#     'contamax': 12.84,
#     'dav': 6.09,
#     'demais': 1.13,
#     'letras': 5.16,
#     'poupanca': 1.68,
#     'time_deposit': 0.59},
#    'carteira': {'captacoes_comex': 83.0,
#     'cdb': 52686.0,
#     'contamax': 27870.0,
#     'dav': 7252.0,
#     'demais': 18436.0,
#     'letras': 2123.0,
#     'poupanca': 751.0,
#     'time_deposit': 68.0},
#    'margem': {'captacoes_comex': 3.2,
#     'cdb': 279.2,
#     'contamax': 3578.5,
#     'dav': 441.6,
#     'demais': 208.3,
#     'letras': 109.5,
#     'poupanca': 12.6,
#     'time_deposit': 0.4}},
#   'cascada': {'cascada': {'bai': 7859.0,
#     'bdi': 4675.0,
#     'demais_ativos': -11.0,
#     'eficiencia': 30.7,
#     'impostos': -3184.0,
#     'mob': 21408.0,
#     'mol': 15508.0,
#     'oryp': -1073.0,
#     'pdd': -5900.0,
#     'rorwa': 5.82,
#     'rwa': 80276.0,
#     'taxa_impositiva': 40.5,
#     'total_gastos': -6565.0},
#    'ppto': {'ppto_bai': 8253.0,
#     'ppto_bdi': 5040.0,
#     'ppto_demais_ativos': -220.0,
#     'ppto_impostos': -3213.0,
#     'ppto_mob': 21926.0,
#     'ppto_mol': 16014.0,
#     'ppto_oryp': -1093.0,
#     'ppto_pdd': -5911.0,
#     'ppto_total_gastos': -6448.0},
#    'atingimento': {'atingimento_bai': 95.23,
#     'atingimento_bdi': 92.76,
#     'atingimento_demais_ativos': 5.0,
#     'atingimento_impostos': 99.1,
#     'atingimento_mob': 97.64,
#     'atingimento_mol': 96.84,
#     'atingimento_oryp': 98.17,
#     'atingimento_pdd': 99.81,
#     'atingimento_total_gastos': 101.81}}},
#  'corporate': {'credito': {'carteira': {'agro': 12673.0,
#     'autos': 1621.0,
#     'capital_de_giro': 2212.0,
#     'comex': 49167.0,
#     'confirming': 5140.0,
#     'conta_garantida': 804.0,
#     'demais': 39558.0,
#     'hipotecas': 1318.0,
#     'internegocios': 3598.0},
#    'spread': {'agro': 2.32,
#     'autos': 3.38,
#     'capital_de_giro': 3.6,
#     'comex': 2.15,
#     'confirming': 4.07,
#     'conta_garantida': 5.77,
#     'demais': 0.77,
#     'hipotecas': 2.09,
#     'internegocios': 1.61},
#    'provisao': {'agro': -8.0,
#     'autos': 0.0,
#     'capital_de_giro': -19.0,
#     'comex': -4.0,
#     'confirming': -21.0,
#     'conta_garantida': -2.0,
#     'demais': -141.0,
#     'hipotecas': -5.0,
#     'internegocios': -4.0},
#    'margem': {'agro': 294.0,
#     'autos': 54.8,
#     'capital_de_giro': 79.6,
#     'comex': 1057.1,
#     'confirming': 209.2,
#     'conta_garantida': 46.4,
#     'demais': 304.2,
#     'hipotecas': 27.5,
#     'internegocios': 57.9},
#    'rwa': {'agro': 9186.0,
#     'autos': 1321.0,
#     'capital_de_giro': 3330.0,
#     'comex': 33518.0,
#     'confirming': 3442.0,
#     'conta_garantida': 1753.0,
#     'demais': 5319.0,
#     'hipotecas': 1307.0,
#     'internegocios': 2155.0}},
#   'comissoes': {'comissoes': {'adquirencia': 164.0,
#     'capitalizacao': 10.0,
#     'cartoes': 39.0,
#     'cash': 0.0,
#     'demais': 1478.0,
#     'fianca': 498.0,
#     'fx': 48.0,
#     'mercado_de_capitais': 264.0,
#     'seguros_open': 39.0,
#     'seguros_related': 16.0}},
#   'captacoes': {'spread': {'captacoes_comex': 2.62,
#     'cdb': 0.39,
#     'contamax': 12.94,
#     'dav': 6.11,
#     'demais': 1.9,
#     'letras': 2.49,
#     'time_deposit': 0.79},
#    'carteira': {'captacoes_comex': 2071.0,
#     'cdb': 41079.0,
#     'contamax': 6038.0,
#     'dav': 3103.0,
#     'demais': 3526.0,
#     'letras': 7197.0,
#     'time_deposit': 2829.0},
#    'margem': {'captacoes_comex': 54.3,
#     'cdb': 160.2,
#     'contamax': 781.3,
#     'dav': 189.6,
#     'demais': 67.10000000000001,
#     'letras': 179.2,
#     'time_deposit': 22.3}},
#   'cascada': {'cascada': {'bai': 5035.0,
#     'bdi': 3315.0,
#     'demais_ativos': 0.0,
#     'eficiencia': 11.6,
#     'impostos': -1720.0,
#     'mob': 6376.0,
#     'mol': 5797.0,
#     'oryp': -20.0,
#     'pdd': -579.0,
#     'rorwa': 3.33,
#     'rwa': 99616.0,
#     'taxa_impositiva': 34.2,
#     'total_gastos': -742.0},
#    'ppto': {'ppto_bai': 4987.0,
#     'ppto_bdi': 3300.0,
#     'ppto_demais_ativos': 0.0,
#     'ppto_impostos': -1687.0,
#     'ppto_mob': 6302.0,
#     'ppto_mol': 5809.0,
#     'ppto_oryp': -19.0,
#     'ppto_pdd': -493.0,
#     'ppto_total_gastos': -803.0},
#    'atingimento': {'atingimento_bai': 100.96,
#     'atingimento_bdi': 100.45,
#     'atingimento_demais_ativos': 0.0,
#     'atingimento_impostos': 101.96,
#     'atingimento_mob': 101.17,
#     'atingimento_mol': 99.79,
#     'atingimento_oryp': 105.26,
#     'atingimento_pdd': 117.44,
#     'atingimento_total_gastos': 92.4}}},
#  'scib': {'credito': {'carteira': {'agro': 2352.0,
#     'autos': 264.0,
#     'capital_de_giro': 4073.0,
#     'cartoes': 164.0,
#     'comex': 32579.0,
#     'confirming': 16530.0,
#     'demais': 103476.0,
#     'hipotecas': 345.0,
#     'internegocios': 15828.0},
#    'spread': {'agro': 1.64,
#     'autos': 4.09,
#     'capital_de_giro': 2.08,
#     'cartoes': 2.01,
#     'comex': 1.41,
#     'confirming': 1.82,
#     'demais': 0.1,
#     'hipotecas': 2.38,
#     'internegocios': 1.0},
#    'provisao': {'agro': -2.0,
#     'autos': 0.0,
#     'capital_de_giro': -340.0,
#     'cartoes': 0.0,
#     'comex': -6.0,
#     'confirming': -897.0,
#     'demais': -956.0,
#     'hipotecas': 0.0,
#     'internegocios': -9.0},
#    'margem': {'agro': 38.6,
#     'autos': 10.8,
#     'capital_de_giro': 84.7,
#     'cartoes': 3.3,
#     'comex': 459.4,
#     'confirming': 300.8,
#     'demais': 105.9,
#     'hipotecas': 8.2,
#     'internegocios': 158.3},
#    'rwa': {'agro': 1029.0,
#     'autos': 238.0,
#     'capital_de_giro': 2237.0,
#     'cartoes': 88.0,
#     'comex': 12667.0,
#     'confirming': 3804.0,
#     'demais': 3872.0,
#     'hipotecas': 262.0,
#     'internegocios': 12836.0}},
#   'comissoes': {'comissoes': {'cash': 0.0,
#     'comex': 191.0,
#     'corretagem': 0.0,
#     'demais': 633.0,
#     'fianca': 0.0,
#     'fx': 0.0,
#     'mercado_de_capitais': 60.0}},
#   'captacoes': {'spread': {'captacoes_comex': 0.27,
#     'cdb': 0.3,
#     'contamax': 8.56,
#     'dav': 7.39,
#     'demais': 1.76,
#     'letras': 2.84,
#     'lf': 0.0,
#     'time_deposit': 0.36},
#    'carteira': {'captacoes_comex': 115973.0,
#     'cdb': 91061.0,
#     'contamax': 5534.0,
#     'dav': 4592.0,
#     'demais': 1658.0,
#     'letras': 3778.0,
#     'lf': 1276.0,
#     'time_deposit': 14084.0},
#    'margem': {'captacoes_comex': 313.1,
#     'cdb': 273.2,
#     'contamax': 473.7,
#     'dav': 339.3,
#     'demais': 29.2,
#     'letras': 107.3,
#     'lf': 0.0,
#     'time_deposit': 50.7}},
#   'cascada': {'cascada': {'bai': 6681.0,
#     'bdi': 4518.0,
#     'demais_ativos': 0.0,
#     'eficiencia': 26.2,
#     'impostos': -2163.0,
#     'mob': 9229.0,
#     'mol': 9120.0,
#     'oryp': -19.0,
#     'pdd': -109.0,
#     'rorwa': 3.68,
#     'rwa': 122660.0,
#     'taxa_impositiva': 32.4,
#     'total_gastos': -2420.0},
#    'ppto': {'ppto_bai': 6669.0,
#     'ppto_bdi': 4842.0,
#     'ppto_demais_ativos': 0.0,
#     'ppto_impostos': -2232.0,
#     'ppto_mob': 9113.0,
#     'ppto_mol': 8998.0,
#     'ppto_oryp': -21.0,
#     'ppto_pdd': -115.0,
#     'ppto_total_gastos': -2308.0},
#    'atingimento': {'atingimento_bai': 100.18,
#     'atingimento_bdi': 93.31,
#     'atingimento_demais_ativos': 0.0,
#     'atingimento_impostos': 96.91,
#     'atingimento_mob': 101.27,
#     'atingimento_mol': 101.36,
#     'atingimento_oryp': 90.48,
#     'atingimento_pdd': 94.78,
#     'atingimento_total_gastos': 104.85}}},
#  'private': {'credito': {'carteira': {'agro': 68.0,
#     'autos': 558.0,
#     'capital_de_giro': 39.0,
#     'cartoes': 486.0,
#     'comex': 2956.0,
#     'cp': 57.0,
#     'demais': 1550.0,
#     'hipotecas': 1863.0,
#     'internegocios': 471.0},
#    'spread': {'agro': 3.38,
#     'autos': 2.33,
#     'capital_de_giro': 1.03,
#     'cartoes': 2.14,
#     'comex': 1.53,
#     'cp': 3.68,
#     'demais': 0.37,
#     'hipotecas': 1.16,
#     'internegocios': 1.89},
#    'provisao': {'agro': 0.0,
#     'autos': 0.0,
#     'capital_de_giro': 0.0,
#     'cartoes': -2.0,
#     'comex': -1.0,
#     'cp': 0.0,
#     'demais': -2.0,
#     'hipotecas': 0.0,
#     'internegocios': 0.0},
#    'margem': {'agro': 2.3,
#     'autos': 13.0,
#     'capital_de_giro': 0.4,
#     'cartoes': 10.4,
#     'comex': 45.2,
#     'cp': 2.1,
#     'demais': 5.7,
#     'hipotecas': 21.6,
#     'internegocios': 8.9},
#    'rwa': {'agro': 30.0,
#     'autos': 520.0,
#     'capital_de_giro': 6.0,
#     'cartoes': 131.0,
#     'comex': 1258.0,
#     'cp': 14.0,
#     'demais': 34.0,
#     'hipotecas': 703.0,
#     'internegocios': 0.0}},
#   'comissoes': {'comissoes': {'cartoes': 32.0,
#     'comex': 0.0,
#     'demais': 208.0,
#     'esfera': 0.0,
#     'fundos': 24.0,
#     'fx': 526.0,
#     'mercado_de_capitais': 0.0,
#     'previdencia': 0.0}},
#   'captacoes': {'spread': {'captacoes_comex': 0.02,
#     'cdb': 0.46,
#     'coe': 0.0,
#     'contamax': 12.43,
#     'dav': 5.5,
#     'demais': 0.13,
#     'letras': 0.37},
#    'carteira': {'captacoes_comex': 1539.0,
#     'cdb': 17431.0,
#     'coe': 947.0,
#     'contamax': 1106.0,
#     'dav': 129.0,
#     'demais': 1167.0,
#     'letras': 54189.0},
#    'margem': {'captacoes_comex': 0.3,
#     'cdb': 80.2,
#     'coe': 0.0,
#     'contamax': 137.5,
#     'dav': 7.1,
#     'demais': 1.5,
#     'letras': 200.5}},
#   'cascada': {'cascada': {'bai': 604.0,
#     'bdi': 388.0,
#     'demais_ativos': 0.0,
#     'eficiencia': 46.0,
#     'impostos': -216.0,
#     'mob': 1130.0,
#     'mol': 1126.0,
#     'oryp': -2.0,
#     'pdd': -4.0,
#     'rorwa': 5.63,
#     'rwa': 6890.0,
#     'taxa_impositiva': 35.8,
#     'total_gastos': -520.0},
#    'ppto': {'ppto_bai': 607.0,
#     'ppto_bdi': 392.0,
#     'ppto_demais_ativos': 0.0,
#     'ppto_impostos': -215.0,
#     'ppto_mob': 1124.0,
#     'ppto_mol': 1109.0,
#     'ppto_oryp': -2.0,
#     'ppto_pdd': -15.0,
#     'ppto_total_gastos': -500.0},
#    'atingimento': {'atingimento_bai': 99.51,
#     'atingimento_bdi': 98.98,
#     'atingimento_demais_ativos': 0.0,
#     'atingimento_impostos': 100.47,
#     'atingimento_mob': 100.53,
#     'atingimento_mol': 101.53,
#     'atingimento_oryp': 100.0,
#     'atingimento_pdd': 26.67,
#     'atingimento_total_gastos': 104.0}}},
#  'consumer': {'credito': {'carteira': {'autos': 64583.0,
#     'cp': 877.0,
#     'demais': 3874.0},
#    'spread': {'autos': 7.81, 'cp': 21.11, 'demais': 8.12},
#    'provisao': {'autos': -3891.0, 'cp': 0.0, 'demais': 0.0},
#    'margem': {'autos': 5043.9, 'cp': 185.1, 'demais': 314.7},
#    'rwa': {'autos': 49758.0, 'cp': 796.0, 'demais': 1234.0}},
#   'comissoes': {'comissoes': {'demais': 133.0,
#     'seguros_open': 0.0,
#     'seguros_related': 0.0,
#     'tarifas_de_credito': 0.0}},
#   'captacoes': {'spread': {'demais': 0},
#    'carteira': {'demais': 0.0},
#    'margem': {'demais': 0.0}},
#   'cascada': {'cascada': {'bai': 2012.0,
#     'bdi': 1209.0,
#     'demais_ativos': 0.0,
#     'eficiencia': 15.9,
#     'impostos': -803.0,
#     'mob': 7218.0,
#     'mol': 3467.0,
#     'oryp': -307.0,
#     'pdd': -3751.0,
#     'rorwa': 1.72,
#     'rwa': 70232.0,
#     'taxa_impositiva': 39.9,
#     'total_gastos': -1148.0},
#    'ppto': {'ppto_bai': 2012.0,
#     'ppto_bdi': 1161.0,
#     'ppto_demais_ativos': 0.0,
#     'ppto_impostos': -851.0,
#     'ppto_mob': 7268.0,
#     'ppto_mol': 3457.0,
#     'ppto_oryp': -297.0,
#     'ppto_pdd': -3811.0,
#     'ppto_total_gastos': -1148.0},
#    'atingimento': {'atingimento_bai': 100.0,
#     'atingimento_bdi': 104.13,
#     'atingimento_demais_ativos': 0.0,
#     'atingimento_impostos': 94.36,
#     'atingimento_mob': 99.31,
#     'atingimento_mol': 100.29,
#     'atingimento_oryp': 103.37,
#     'atingimento_pdd': 98.43,
#     'atingimento_total_gastos': 100.0}}},
#  'total': {'cascada': {'cascada': {'bai': 25843.0,
#     'bdi': 15236.0,
#     'demais_ativos': -314.0,
#     'eficiencia': 31.9,
#     'impostos': -10607.0,
#     'mob': 81922.0,
#     'mol': 55393.0,
#     'oryp': -3107.0,
#     'pdd': -26529.0,
#     'rorwa': 2.54,
#     'rwa': 600644.0,
#     'taxa_impositiva': 41.0,
#     'total_gastos': -26129.0},
#    'ppto': {'ppto_bai': 27120.0,
#     'ppto_bdi': 16480.0,
#     'ppto_demais_ativos': -548.0,
#     'ppto_impostos': -10640.0,
#     'ppto_mob': 82847.0,
#     'ppto_mol': 56498.0,
#     'ppto_oryp': -3130.0,
#     'ppto_pdd': -26349.0,
#     'ppto_total_gastos': -25700.0},
#    'atingimento': {'atingimento_bai': 95.29,
#     'atingimento_bdi': 92.45,
#     'atingimento_demais_ativos': 57.3,
#     'atingimento_impostos': 99.69,
#     'atingimento_mob': 98.88,
#     'atingimento_mol': 98.04,
#     'atingimento_oryp': 99.27,
#     'atingimento_pdd': 100.68,
#     'atingimento_total_gastos': 101.67}}}}

# %%
import json

with open("dict_indicadores.json", "w", encoding="utf-8") as f:
    json.dump(dict_indicadores, f, indent=4, ensure_ascii=False)
