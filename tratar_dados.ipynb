# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel("base_indicadores.xlsx", sheet_name="indicadores", engine="openpyxl")
df.columns = df.columns.str.lower()

# %%
df.loc[df["indicador"] == "cascada_ppto", "topico"] = "cascada"
df.loc[df["indicador"] == "cascada_ppto", "indicador"] = "ppto"

# %%
import unicodedata

def remover_acentos(texto):
    if isinstance(texto, str):
        nfkd = unicodedata.normalize("NFKD", texto)
        return "".join([char for char in nfkd if not unicodedata.combining(char)])
    return texto

# Tratando textos
df["abertura"] = df["abertura"].apply(remover_acentos)
df["abertura"] = df["abertura"].str.lower()
df["abertura"] = df["abertura"].str.replace(" ", "_")
df["abertura"] = df["abertura"].str.replace("-", "_")
df["abertura"] = df["abertura"].str.replace("(", "")
df["abertura"] = df["abertura"].str.replace(")", "")
df["abertura"] = df["abertura"].str.replace("/", "_")

df["topico"] = df["topico"].str.replace(" ", "_") # Off Balance

# %%
df[df["abertura"] == "rorwa"]
# Out:
# Empty DataFrame
# Columns: [topico, indicador, abertura, especial, prospera, select, pj, corporate, scib, private, consumer, total]
# Index: []

# %%
segmentos = ["especial", "prospera", "select", "pj", "corporate", "scib", "private", "consumer"]
df.loc[df["indicador"] == "spread", segmentos] = (df.loc[df["indicador"] == "spread", segmentos] * 100).round(2)
df.loc[df["abertura"].isin(["rorwa", "ppto_taxa_impositiva", "ppto_eficiencia"]), segmentos] = df.loc[df["abertura"].isin(["rorwa", "ppto_taxa_impositiva", "ppto_eficiencia"]), segmentos] * 100

# %%
# calculando o atingimento do cascada
indicadores_atingimento = df.loc[(df["indicador"] == "cascada") & (~df["abertura"].isin(["rwa", "rorwa"]))]["abertura"].unique()

realizado = df.loc[(df["indicador"] == "cascada") & (~df["abertura"].isin(["rwa", "rorwa"]))][segmentos + ['total']].reset_index(drop=True)
ppto = df.loc[(df["indicador"] == "ppto")][segmentos + ['total']].reset_index(drop=True)

resultado_divisao = (realizado / ppto * 100).fillna(0)

resultado_divisao["topico"] = "cascada"
resultado_divisao["indicador"] = "atingimento"
resultado_divisao["abertura"] = [f"atingimento_{i}" for i in indicadores_atingimento]

df = pd.concat([df, resultado_divisao[["topico", "indicador", "abertura"] + segmentos + ['total']]], ignore_index=True)

# %%
# calculando a taxa impositiva, eficiência e rorwa

mob = df.loc[(df["indicador"] == "cascada") & (df["abertura"].isin(["mob"]))][segmentos + ['total']].reset_index(drop=True).fillna(0)
gastos = df.loc[(df["indicador"] == "cascada") & (df["abertura"].isin(["total_gastos"]))][segmentos + ['total']].reset_index(drop=True).fillna(0)

bai = df.loc[(df["indicador"] == "cascada") & (df["abertura"].isin(["bai"]))][segmentos + ['total']].reset_index(drop=True).fillna(0)
impostos = df.loc[(df["indicador"] == "cascada") & (df["abertura"].isin(["impostos"]))][segmentos + ['total']].reset_index(drop=True).fillna(0)

bdi = df.loc[(df["indicador"] == "cascada") & (df["abertura"].isin(["bdi"]))][segmentos + ['total']].reset_index(drop=True).fillna(0)
rwa = df.loc[(df["indicador"] == "cascada") & (df["abertura"].isin(["rwa"]))][segmentos + ['total']].reset_index(drop=True).fillna(0)

eficiencia = round(-gastos / mob * 100, 1)
eficiencia["abertura"] = "eficiencia"
taxa_impositiva = round(-impostos / bai * 100, 1)
taxa_impositiva["abertura"] = "taxa_impositiva"
rorwa = round(bdi / rwa * 100, 1)
rorwa["abertura"] = "rorwa"

df_aux = pd.concat([eficiencia, taxa_impositiva, rorwa], ignore_index=True)
df_aux["indicador"] = "cascada"
df_aux["topico"] = "cascada"

df_aux = df_aux[["topico", "indicador", "abertura"] + segmentos + ['total']]
df = pd.concat([df, df_aux], ignore_index=True)

# %%
gastos
# Out:
#    especial  prospera  select      pj  corporate    scib  private  consumer  \
# 0   -5761.0    -453.0 -7507.0 -6565.0     -742.0 -2420.0   -520.0   -1148.0
#
#      total
# 0 -26129.0

# %%
bdi
# Out:
#    especial  prospera  select      pj  corporate    scib  private  consumer  \
# 0   -1735.0     176.0  2328.0  4675.0     3315.0  4518.0    388.0    1209.0
#
#      total
# 0  15236.0

# %%
rwa
# Out:
#    especial  prospera    select       pj  corporate      scib  private  \
# 0  41286.86   1143.07  59090.22  80276.0    99616.0  122660.0   6890.0
#
#    consumer     total
# 0   70232.0  600644.0

# %%
176.0 / 1143.07
# Out:
# 0.15397132284112086

# %%
rorwa
# Out:
#    especial  prospera  select   pj  corporate  scib  private  consumer  total  \
# 0      -4.2      15.4     3.9  5.8        3.3   3.7      5.6       1.7    2.5
#
#   abertura
# 0    rorwa

# %%
for col in df.select_dtypes(include=['number']).columns:
    df[col] = df[col].round(1)

# %%
df[df["topico"] == "cascada"]
# Out:
#       topico    indicador                   abertura  especial  prospera  \
# 149  cascada      cascada                        mob   14768.0    1269.0
# 150  cascada      cascada                        pdd   -9698.0    -412.0
# 151  cascada      cascada                        mol    5070.0     857.0
# 152  cascada      cascada                       oryp    -972.0     -70.0
# 153  cascada      cascada              demais_ativos    -185.0      -1.0
# 154  cascada      cascada               total_gastos   -5761.0    -453.0
# 155  cascada      cascada                        bai   -1848.0     333.0
# 156  cascada      cascada                   impostos     113.0    -157.0
# 157  cascada      cascada                        bdi   -1735.0     176.0
# 158  cascada      cascada                        rwa   41286.9    1143.1
# 159  cascada         ppto                   ppto_mob   15351.0    1666.0
# 160  cascada         ppto                   ppto_pdd   -9771.0    -390.0
# 161  cascada         ppto                   ppto_mol    5580.0    1276.0
# 162  cascada         ppto                  ppto_oryp   -1298.0     -95.0
# 163  cascada         ppto         ppto_demais_ativos    -144.0      -8.0
# 164  cascada         ppto          ppto_total_gastos   -5717.0    -440.0
# 165  cascada         ppto                   ppto_bai    1579.0     733.0
# 166  cascada         ppto              ppto_impostos     -59.0    -277.0
# 167  cascada         ppto                   ppto_bdi    1638.0     456.0
# 168  cascada  atingimento            atingimento_mob      96.2      76.2
# 169  cascada  atingimento            atingimento_pdd      99.3     105.6
# 170  cascada  atingimento            atingimento_mol      90.9      67.2
# 171  cascada  atingimento           atingimento_oryp      74.9      73.7
# 172  cascada  atingimento  atingimento_demais_ativos     128.5      12.5
# 173  cascada  atingimento   atingimento_total_gastos     100.8     103.0
# 174  cascada  atingimento            atingimento_bai    -117.0      45.4
# 175  cascada  atingimento       atingimento_impostos    -191.5      56.7
# 176  cascada  atingimento            atingimento_bdi    -105.9      38.6
# 177  cascada      cascada                 eficiencia      39.0      35.7
# 178  cascada      cascada            taxa_impositiva       6.1      47.1
# 179  cascada      cascada                      rorwa      -4.2      15.4
#
#       select       pj  corporate      scib  private  consumer     total
# 149  18966.0  21408.0     6376.0    9229.0   1130.0    7218.0   81922.0
# 150  -6047.0  -5900.0     -579.0    -109.0     -4.0   -3751.0  -26529.0
# 151  12919.0  15508.0     5797.0    9120.0   1126.0    3467.0   55393.0
# 152   -834.0  -1073.0      -20.0     -19.0     -2.0    -307.0   -3107.0
# 153    -74.0    -11.0        0.0       0.0      0.0       0.0    -314.0
# 154  -7507.0  -6565.0     -742.0   -2420.0   -520.0   -1148.0  -26129.0
# 155   4504.0   7859.0     5035.0    6681.0    604.0    2012.0   25843.0
# 156  -2176.0  -3184.0    -1720.0   -2163.0   -216.0    -803.0  -10607.0
# 157   2328.0   4675.0     3315.0    4518.0    388.0    1209.0   15236.0
# 158  59090.2  80276.0    99616.0  122660.0   6890.0   70232.0  600644.0
# 159  18511.0  21926.0     6302.0    9113.0   1124.0    7268.0   82847.0
# 160  -5841.0  -5911.0     -493.0    -115.0    -15.0   -3811.0  -26349.0
# 161  12669.0  16014.0     5809.0    8998.0   1109.0    3457.0   56498.0
# 162   -479.0  -1093.0      -19.0     -21.0     -2.0    -297.0   -3130.0
# 163   -163.0   -220.0        0.0       0.0      0.0       0.0    -548.0
# 164  -7347.0  -6448.0     -803.0   -2308.0   -500.0   -1148.0  -25700.0
# 165   4680.0   8253.0     4987.0    6669.0    607.0    2012.0   27120.0
# 166  -2090.0  -3213.0    -1687.0   -2232.0   -215.0    -851.0  -10640.0
# 167   2590.0   5040.0     3300.0    4842.0    392.0    1161.0   16480.0
# 168    102.5     97.6      101.2     101.3    100.5      99.3      98.9
# 169    103.5     99.8      117.4      94.8     26.7      98.4     100.7
# 170    102.0     96.8       99.8     101.4    101.5     100.3      98.0
# 171    174.1     98.2      105.3      90.5    100.0     103.4      99.3
# 172     45.4      5.0        0.0       0.0      0.0       0.0      57.3
# 173    102.2    101.8       92.4     104.9    104.0     100.0     101.7
# 174     96.2     95.2      101.0     100.2     99.5     100.0      95.3
# 175    104.1     99.1      102.0      96.9    100.5      94.4      99.7
# 176     89.9     92.8      100.5      93.3     99.0     104.1      92.5
# 177     39.6     30.7       11.6      26.2     46.0      15.9      31.9
# 178     48.3     40.5       34.2      32.4     35.8      39.9      41.0
# 179      3.9      5.8        3.3       3.7      5.6       1.7       2.5

# %%
# df_melted = df.melt(id_vars=["Topico", "Indicador", "Abertura"], var_name="Segmento", value_name="Valor")

# %%
aberturas_segmento = {
    "credito": {
        "especial": ['cheque especial', 'cartões', 'cp', 'consignado', 'hipotecas', 'autos', 'demais'],
        "prospera": ['cheque especial', 'cartões', 'cp', 'consignado', 'hipotecas', 'autos', 'microcrédito', 'demais'],
        "select": ['cheque especial', 'cartões', 'cp', 'consignado', 'hipotecas', 'autos', 'agro', 'comex', 'demais'],
        "pj": ['cheque emp/adp', 'cartões', 'hipotecas', 'autos', 'agro', 'capital de giro', 'comex', 'conta garantida', 'confirming', 'internegócios', 'demais'],
        "corporate": ['hipotecas', 'autos', 'agro', 'capital de giro', 'comex', 'conta garantida', 'confirming', 'internegócios', 'demais'],
        "scib": ['cartões', 'hipotecas', 'autos', 'agro', 'capital de giro', 'comex', 'confirming', 'internegócios', 'demais'],
        "private": ['cartões', 'cp', 'hipotecas', 'autos', 'agro', 'capital de giro', 'comex', 'internegócios', 'demais'],
        "consumer": ['cp', 'autos', 'demais']
    },

    "captacoes": {
        "especial": ['dav', 'contamax', 'cdb', 'poupança', 'letras', 'demais'],
        "prospera": ['dav', 'contamax', 'cdb', 'poupança', 'letras', 'demais'],
        "select": ['dav', 'contamax', 'cdb', 'poupança', 'letras', 'captações comex', 'demais'],
        "pj": ['dav', 'contamax', 'cdb', 'poupança', 'letras', 'captações comex', 'time deposit', 'demais'],
        "corporate": ['dav', 'contamax', 'cdb', 'letras', 'captações comex', 'time deposit', 'demais'],
        "scib": ['dav', 'contamax', 'cdb', 'letras', 'captações comex', 'time deposit', 'lf', 'demais'],
        "private": ['dav', 'contamax', 'cdb', 'letras', 'captações comex', 'coe', 'demais'],
        "consumer": []
    },

    "comissoes": {
        "especial": ['cartões', 'seguros open', 'seguros related', 'tarifas c/c', 'capitalização', 'consórcio', 'esfera', 'fidelização inss', 'tecban', 'demais'],
        "prospera": ['cartões', 'seguros open', 'seguros related', 'tarifas c/c', 'capitalização', 'consórcio', 'esfera', 'fidelização inss', 'tecban', 'demais'],
        "select": ['cartões', 'seguros open', 'seguros related', 'tarifas c/c', 'capitalização', 'consórcio', 'esfera', 'tecban', 'aaa', 'demais'],
        "pj": ['cartões', 'seguros open', 'seguros related', 'tarifas c/c', 'capitalização', 'consórcio', 'esfera', 'tecban', 'abertura conta', 'adquirência', 'fx', 'cash', 'demais'],
        "corporate": ['cartões', 'seguros open', 'seguros related', 'tarifas c/c', 'capitalização', 'consórcio', 'mercado de capitais', 'fiança', 'abertura conta', 'adquirência', 'fx', 'cash', 'demais'],
        "scib": ['mercado de capitais', 'fx', 'fiança', 'comex', 'cash', 'corretagem', 'demais'],
        "private": ['previdência', 'fundos', 'fx', 'mercado de capitais', 'comex', 'esfera', 'cartões', 'demais'],
        "consumer": ['seguros open', 'seguros related', 'tarifas de crédito', 'demais']
    }
}

# %%
for k in aberturas_segmento:
    for abertura in aberturas_segmento[k]:
        aberturas_segmento[k][abertura] = [i.replace(" ", "_") for i in aberturas_segmento[k][abertura]]
        aberturas_segmento[k][abertura] = [i.replace("/", "") for i in aberturas_segmento[k][abertura]]
        aberturas_segmento[k][abertura] = [remover_acentos(i) for i in aberturas_segmento[k][abertura]]

# %%
def calculate_spread(df, segmentos):
    new_spread = pd.DataFrame(
        np.array(
            df.loc[df["indicador"] == "margem"][segmentos].astype("float")) /
             np.array(df.loc[df["indicador"] == "carteira"][segmentos].astype("float")) * 100,
        columns=segmentos
    ).fillna(0)
    df.loc[df["indicador"] == "spread", segmentos] = np.array(new_spread)
    return df

# %%
def get_numbers(df, topico, indicador, segmento, aberturas_segmento):
    new_df = df.loc[(df["topico"] == topico) & (df["indicador"] == indicador), ["abertura", segmento]]
    if topico not in ["cascada"]:
        if segmento in ["especial", "prospera", "select"]:
            new_df["abertura"] = new_df["abertura"].apply(lambda x: "cheque_especial" if x == "cheque" else x)
        elif segmento == "PJ":
            new_df["abertura"] = new_df["abertura"].apply(lambda x: "cheque_empadp" if x == "cheque" else x)
        if segmento != "total":
            new_df["abertura"] = new_df["abertura"].apply(lambda x: x if x in aberturas_segmento[topico][segmento] else "demais")
    else:
        new_df = df.loc[(df["topico"] == topico) & (df["indicador"] == indicador), ["abertura", segmento]]
        
    return new_df.groupby(["abertura"])[segmento].sum().round(2).to_dict()

# %%
gastos
# Out:
#    especial  prospera  select      pj  corporate    scib  private  consumer  \
# 0   -5761.0    -453.0 -7507.0 -6565.0     -742.0 -2420.0   -520.0   -1148.0
#
#      total
# 0 -26129.0

# %%
df[df["abertura"] == "rorwa"]
# Out:
#       topico indicador abertura  especial  prospera  select   pj  corporate  \
# 179  cascada   cascada    rorwa      -4.2      15.4     3.9  5.8        3.3
#
#      scib  private  consumer  total
# 179   3.7      5.6       1.7    2.5

# %%
get_numbers(df, "cascada", "cascada", "prospera", aberturas_segmento)
# indicador = ['cascada', 'ppto', 'atingimento']
# ['carteira', 'spread', 'provisao', 'margem', 'rwa']
# Out:
# {'bai': 333.0,
#  'bdi': 176.0,
#  'demais_ativos': -1.0,
#  'eficiencia': 35.7,
#  'impostos': -157.0,
#  'mob': 1269.0,
#  'mol': 857.0,
#  'oryp': -70.0,
#  'pdd': -412.0,
#  'rorwa': 15.4,
#  'rwa': 1143.1,
#  'taxa_impositiva': 47.1,
#  'total_gastos': -453.0}

# %%
topicos = df["topico"].unique()
segmentos = ["especial", "prospera", "select", "pj", "corporate", "scib", "private", "consumer", "total"]
segmentos = [s.lower() for s in segmentos]
indicadores = df.groupby("topico")["indicador"].unique().to_dict()
indicadores_cascada = df.loc[df["topico"] == "cascada", "abertura"].unique()
# indicadores_cascada_ppto = df.loc[df["topico"] == "cascada_ppto", "abertura"].unique()

# %%
topicos
# Out:
# array(['credito', 'comissoes', 'captacoes', 'off_balance', 'cascada'],
#       dtype=object)

# %%
indicadores
# Out:
# {'captacoes': array(['spread', 'carteira', 'margem'], dtype=object),
#  'cascada': array(['cascada', 'ppto', 'atingimento'], dtype=object),
#  'comissoes': array(['comissoes'], dtype=object),
#  'credito': array(['carteira', 'spread', 'provisao', 'margem', 'rwa'], dtype=object),
#  'off_balance': array(['spread', 'carteira', 'margem'], dtype=object)}

# %%
segmentos
# Out:
# ['especial',
#  'prospera',
#  'select',
#  'pj',
#  'corporate',
#  'scib',
#  'private',
#  'consumer',
#  'total']

# %%
dict_indicadores = dict()
for segmento in segmentos:
    dict_indicadores[segmento] = {}
    for topico in topicos:
        if (topico == "off_balance") | (segmento == "total" and topico != "cascada"):
            continue
        dict_indicadores[segmento][topico] = {}
        for indicador in indicadores[topico]:
            dict_resultado = get_numbers(df, topico, indicador, segmento, aberturas_segmento)

            if topico == ["comissoes"]:
                dict_indicadores[segmento][topico] = dict_resultado
            else:
                dict_indicadores[segmento][topico][indicador] = dict_resultado

# %%
dict_indicadores
# Out:
# {'especial': {'credito': {'carteira': {'autos': 4970.0,
#     'cartoes': 20157.0,
#     'cheque_especial': 1747.0,
#     'consignado': 38458.0,
#     'cp': 6964.0,
#     'demais': 67.0,
#     'hipotecas': 11632.0},
#    'spread': {'autos': 9.4,
#     'cartoes': 17.0,
#     'cheque_especial': 89.5,
#     'consignado': 8.6,
#     'cp': 22.3,
#     'demais': 50.2,
#     'hipotecas': 1.5},
#    'provisao': {'autos': 380.0,
#     'cartoes': 3317.0,
#     'cheque_especial': 477.0,
#     'consignado': 1957.0,
#     'cp': 2917.0,
#     'demais': 22.0,
#     'hipotecas': 68.0},
#    'margem': {'autos': 465.0,
#     'cartoes': 3430.0,
#     'cheque_especial': 1564.0,
#     'consignado': 3294.0,
#     'cp': 1555.0,
#     'demais': 18.0,
#     'hipotecas': 171.0},
#    'rwa': {'autos': 3519.0,
#     'cartoes': 7841.0,
#     'cheque_especial': 1067.0,
#     'consignado': 22553.0,
#     'cp': 2496.0,
#     'demais': 28.0,
#     'hipotecas': 3579.0}},
#   'comissoes': {'comissoes': {'capitalizacao': 448.0,
#     'cartoes': 1654.0,
#     'demais': 1822.0,
#     'esfera': 33.0,
#     'fidelizacao_inss': 266.0,
#     'seguros_open': 597.0,
#     'seguros_related': 491.0,
#     'tecban': 0.0}},
#   'captacoes': {'spread': {'cdb': 0.5,
#     'contamax': 12.6,
#     'dav': 6.3,
#     'demais': 11.7,
#     'letras': 0.7,
#     'poupanca': 1.7},
#    'carteira': {'cdb': 5517.0,
#     'contamax': 11509.0,
#     'dav': 706.0,
#     'demais': 859.0,
#     'letras': 800.0,
#     'poupanca': 18838.0},
#    'margem': {'cdb': 30.0,
#     'contamax': 1456.0,
#     'dav': 44.0,
#     'demais': 54.0,
#     'letras': 5.0,
#     'poupanca': 316.0}},
#   'cascada': {'cascada': {'bai': -1848.0,
#     'bdi': -1735.0,
#     'demais_ativos': -185.0,
#     'eficiencia': 39.0,
#     'impostos': 113.0,
#     'mob': 14768.0,
#     'mol': 5070.0,
#     'oryp': -972.0,
#     'pdd': -9698.0,
#     'rorwa': -4.2,
#     'rwa': 41286.9,
#     'taxa_impositiva': 6.1,
#     'total_gastos': -5761.0},
#    'ppto': {'ppto_bai': 1579.0,
#     'ppto_bdi': 1638.0,
#     'ppto_demais_ativos': -144.0,
#     'ppto_impostos': -59.0,
#     'ppto_mob': 15351.0,
#     'ppto_mol': 5580.0,
#     'ppto_oryp': -1298.0,
#     'ppto_pdd': -9771.0,
#     'ppto_total_gastos': -5717.0},
#    'atingimento': {'atingimento_bai': -117.0,
#     'atingimento_bdi': -105.9,
#     'atingimento_demais_ativos': 128.5,
#     'atingimento_impostos': -191.5,
#     'atingimento_mob': 96.2,
#     'atingimento_mol': 90.9,
#     'atingimento_oryp': 74.9,
#     'atingimento_pdd': 99.3,
#     'atingimento_total_gastos': 100.8}}},
#  'prospera': {'credito': {'carteira': {'autos': 184.0,
#     'cartoes': 182.0,
#     'cheque_especial': 18.0,
#     'consignado': 1494.0,
#     'cp': 44.0,
#     'demais': 0.0,
#     'hipotecas': 107.0,
#     'microcredito': 2719.0},
#    'spread': {'autos': 9.2,
#     'cartoes': 17.7,
#     'cheque_especial': 92.8,
#     'consignado': 6.9,
#     'cp': 22.6,
#     'demais': 0.0,
#     'hipotecas': 1.5,
#     'microcredito': 36.1},
#    'provisao': {'autos': 28.0,
#     'cartoes': 181.0,
#     'cheque_especial': 10.0,
#     'consignado': 96.0,
#     'cp': 34.0,
#     'demais': 0.0,
#     'hipotecas': 0.0,
#     'microcredito': 213.0},
#    'margem': {'autos': 17.0,
#     'cartoes': 32.0,
#     'cheque_especial': 17.0,
#     'consignado': 103.0,
#     'cp': 10.0,
#     'demais': 0.0,
#     'hipotecas': 2.0,
#     'microcredito': 982.0},
#    'rwa': {'autos': 130.0,
#     'cartoes': 71.0,
#     'cheque_especial': 11.0,
#     'consignado': 876.0,
#     'cp': 16.0,
#     'demais': 0.0,
#     'hipotecas': 33.0,
#     'microcredito': 1411.0}},
#   'comissoes': {'comissoes': {'capitalizacao': 12.0,
#     'cartoes': 76.0,
#     'demais': 37.0,
#     'esfera': 0.0,
#     'fidelizacao_inss': 0.0,
#     'seguros_open': 12.0,
#     'seguros_related': 22.0,
#     'tecban': 2.0}},
#   'captacoes': {'spread': {'cdb': 0.5,
#     'contamax': 12.7,
#     'dav': 6.3,
#     'demais': 16.2,
#     'letras': 0.7,
#     'poupanca': 1.6},
#    'carteira': {'cdb': 81.0,
#     'contamax': 218.0,
#     'dav': 75.0,
#     'demais': 12.0,
#     'letras': 7.0,
#     'poupanca': 1145.0},
#    'margem': {'cdb': 0.0,
#     'contamax': 28.0,
#     'dav': 5.0,
#     'demais': 2.0,
#     'letras': 0.0,
#     'poupanca': 19.0}},
#   'cascada': {'cascada': {'bai': 333.0,
#     'bdi': 176.0,
#     'demais_ativos': -1.0,
#     'eficiencia': 35.7,
#     'impostos': -157.0,
#     'mob': 1269.0,
#     'mol': 857.0,
#     'oryp': -70.0,
#     'pdd': -412.0,
#     'rorwa': 15.4,
#     'rwa': 1143.1,
#     'taxa_impositiva': 47.1,
#     'total_gastos': -453.0},
#    'ppto': {'ppto_bai': 733.0,
#     'ppto_bdi': 456.0,
#     'ppto_demais_ativos': -8.0,
#     'ppto_impostos': -277.0,
#     'ppto_mob': 1666.0,
#     'ppto_mol': 1276.0,
#     'ppto_oryp': -95.0,
#     'ppto_pdd': -390.0,
#     'ppto_total_gastos': -440.0},
#    'atingimento': {'atingimento_bai': 45.4,
#     'atingimento_bdi': 38.6,
#     'atingimento_demais_ativos': 12.5,
#     'atingimento_impostos': 56.7,
#     'atingimento_mob': 76.2,
#     'atingimento_mol': 67.2,
#     'atingimento_oryp': 73.7,
#     'atingimento_pdd': 105.6,
#     'atingimento_total_gastos': 103.0}}},
#  'select': {'credito': {'carteira': {'agro': 7002.0,
#     'autos': 3906.0,
#     'cartoes': 27769.0,
#     'cheque_especial': 2610.0,
#     'comex': 2111.0,
#     'consignado': 19940.0,
#     'cp': 6817.0,
#     'demais': 18710.0,
#     'hipotecas': 53263.0},
#    'spread': {'agro': 5.8,
#     'autos': 6.9,
#     'cartoes': 9.8,
#     'cheque_especial': 79.9,
#     'comex': 2.6,
#     'consignado': 8.2,
#     'cp': 22.6,
#     'demais': 131.3,
#     'hipotecas': 1.2},
#    'provisao': {'agro': 210.0,
#     'autos': 200.0,
#     'cartoes': 1585.0,
#     'cheque_especial': 327.0,
#     'comex': 4.0,
#     'consignado': 552.0,
#     'cp': 2269.0,
#     'demais': 78.0,
#     'hipotecas': 208.0},
#    'margem': {'agro': 408.0,
#     'autos': 268.0,
#     'cartoes': 2711.0,
#     'cheque_especial': 2086.0,
#     'comex': 55.0,
#     'consignado': 1625.0,
#     'cp': 1538.0,
#     'demais': 288.0,
#     'hipotecas': 652.0},
#    'rwa': {'agro': 3944.0,
#     'autos': 2766.0,
#     'cartoes': 10801.0,
#     'cheque_especial': 1594.0,
#     'comex': 1175.0,
#     'consignado': 11694.0,
#     'cp': 2443.0,
#     'demais': 7542.0,
#     'hipotecas': 16390.0}},
#   'comissoes': {'comissoes': {'aaa': 62.0,
#     'capitalizacao': 1439.0,
#     'cartoes': 2153.0,
#     'demais': 4789.0,
#     'esfera': 373.0,
#     'seguros_open': 781.0,
#     'seguros_related': 661.0,
#     'tecban': 12.0}},
#   'captacoes': {'spread': {'captacoes_comex': 5.6,
#     'cdb': 0.8,
#     'contamax': 12.7,
#     'dav': 6.3,
#     'demais': 0.2,
#     'letras': 0.7,
#     'poupanca': 1.7},
#    'carteira': {'captacoes_comex': 118.0,
#     'cdb': 68322.0,
#     'contamax': 19871.0,
#     'dav': 498.0,
#     'demais': 30864.0,
#     'letras': 20373.0,
#     'poupanca': 34844.0},
#    'margem': {'captacoes_comex': 7.0,
#     'cdb': 512.0,
#     'contamax': 2518.0,
#     'dav': 31.0,
#     'demais': 64.0,
#     'letras': 274.0,
#     'poupanca': 575.0}},
#   'cascada': {'cascada': {'bai': 4504.0,
#     'bdi': 2328.0,
#     'demais_ativos': -74.0,
#     'eficiencia': 39.6,
#     'impostos': -2176.0,
#     'mob': 18966.0,
#     'mol': 12919.0,
#     'oryp': -834.0,
#     'pdd': -6047.0,
#     'rorwa': 3.9,
#     'rwa': 59090.2,
#     'taxa_impositiva': 48.3,
#     'total_gastos': -7507.0},
#    'ppto': {'ppto_bai': 4680.0,
#     'ppto_bdi': 2590.0,
#     'ppto_demais_ativos': -163.0,
#     'ppto_impostos': -2090.0,
#     'ppto_mob': 18511.0,
#     'ppto_mol': 12669.0,
#     'ppto_oryp': -479.0,
#     'ppto_pdd': -5841.0,
#     'ppto_total_gastos': -7347.0},
#    'atingimento': {'atingimento_bai': 96.2,
#     'atingimento_bdi': 89.9,
#     'atingimento_demais_ativos': 45.4,
#     'atingimento_impostos': 104.1,
#     'atingimento_mob': 102.5,
#     'atingimento_mol': 102.0,
#     'atingimento_oryp': 174.1,
#     'atingimento_pdd': 103.5,
#     'atingimento_total_gastos': 102.2}}},
#  'pj': {'credito': {'carteira': {'agro': 1169.0,
#     'autos': 4791.0,
#     'capital_de_giro': 30441.0,
#     'cartoes': 4088.0,
#     'comex': 15184.0,
#     'confirming': 985.0,
#     'conta_garantida': 3113.0,
#     'demais': 23184.0,
#     'hipotecas': 2377.0,
#     'internegocios': 834.0},
#    'spread': {'agro': 4.9,
#     'autos': 5.4,
#     'capital_de_giro': 9.4,
#     'cartoes': 14.9,
#     'comex': 3.2,
#     'confirming': 3.6,
#     'conta_garantida': 16.8,
#     'demais': 180.5,
#     'hipotecas': 2.3,
#     'internegocios': 1.1},
#    'provisao': {'agro': 4.0,
#     'autos': 273.0,
#     'capital_de_giro': 1116.0,
#     'cartoes': 605.0,
#     'comex': 41.0,
#     'confirming': 11.0,
#     'conta_garantida': 154.0,
#     'demais': 806.0,
#     'hipotecas': 16.0,
#     'internegocios': 0.0},
#    'margem': {'agro': 57.0,
#     'autos': 259.0,
#     'capital_de_giro': 2850.0,
#     'cartoes': 609.0,
#     'comex': 481.0,
#     'confirming': 35.0,
#     'conta_garantida': 522.0,
#     'demais': 4385.0,
#     'hipotecas': 55.0,
#     'internegocios': 10.0},
#    'rwa': {'agro': 758.0,
#     'autos': 3617.0,
#     'capital_de_giro': 20078.0,
#     'cartoes': 2057.0,
#     'comex': 10603.0,
#     'confirming': 930.0,
#     'conta_garantida': 1942.0,
#     'demais': 5087.0,
#     'hipotecas': 1832.0,
#     'internegocios': 87.0}},
#   'comissoes': {'comissoes': {'adquirencia': 17.0,
#     'capitalizacao': 28.0,
#     'cartoes': 576.0,
#     'cash': 12.0,
#     'demais': 2661.0,
#     'esfera': 431.0,
#     'fx': 100.0,
#     'seguros_open': 576.0,
#     'seguros_related': 254.0,
#     'tecban': 82.0}},
#   'captacoes': {'spread': {'captacoes_comex': 3.8,
#     'cdb': 0.5,
#     'contamax': 12.8,
#     'dav': 6.1,
#     'demais': 2.3,
#     'letras': 5.2,
#     'poupanca': 1.7,
#     'time_deposit': 0.6},
#    'carteira': {'captacoes_comex': 83.0,
#     'cdb': 52686.0,
#     'contamax': 27870.0,
#     'dav': 7252.0,
#     'demais': 18436.0,
#     'letras': 2123.0,
#     'poupanca': 751.0,
#     'time_deposit': 68.0},
#    'margem': {'captacoes_comex': 3.0,
#     'cdb': 286.0,
#     'contamax': 3578.0,
#     'dav': 441.0,
#     'demais': 416.0,
#     'letras': 110.0,
#     'poupanca': 13.0,
#     'time_deposit': 0.0}},
#   'cascada': {'cascada': {'bai': 7859.0,
#     'bdi': 4675.0,
#     'demais_ativos': -11.0,
#     'eficiencia': 30.7,
#     'impostos': -3184.0,
#     'mob': 21408.0,
#     'mol': 15508.0,
#     'oryp': -1073.0,
#     'pdd': -5900.0,
#     'rorwa': 5.8,
#     'rwa': 80276.0,
#     'taxa_impositiva': 40.5,
#     'total_gastos': -6565.0},
#    'ppto': {'ppto_bai': 8253.0,
#     'ppto_bdi': 5040.0,
#     'ppto_demais_ativos': -220.0,
#     'ppto_impostos': -3213.0,
#     'ppto_mob': 21926.0,
#     'ppto_mol': 16014.0,
#     'ppto_oryp': -1093.0,
#     'ppto_pdd': -5911.0,
#     'ppto_total_gastos': -6448.0},
#    'atingimento': {'atingimento_bai': 95.2,
#     'atingimento_bdi': 92.8,
#     'atingimento_demais_ativos': 5.0,
#     'atingimento_impostos': 99.1,
#     'atingimento_mob': 97.6,
#     'atingimento_mol': 96.8,
#     'atingimento_oryp': 98.2,
#     'atingimento_pdd': 99.8,
#     'atingimento_total_gastos': 101.8}}},
#  'corporate': {'credito': {'carteira': {'agro': 12673.0,
#     'autos': 1621.0,
#     'capital_de_giro': 2212.0,
#     'comex': 49167.0,
#     'confirming': 5140.0,
#     'conta_garantida': 804.0,
#     'demais': 39558.0,
#     'hipotecas': 1318.0,
#     'internegocios': 3598.0},
#    'spread': {'agro': 2.3,
#     'autos': 3.4,
#     'capital_de_giro': 3.6,
#     'comex': 2.2,
#     'confirming': 4.1,
#     'conta_garantida': 5.8,
#     'demais': 193.3,
#     'hipotecas': 2.1,
#     'internegocios': 1.6},
#    'provisao': {'agro': 8.0,
#     'autos': 0.0,
#     'capital_de_giro': 19.0,
#     'comex': 4.0,
#     'confirming': 21.0,
#     'conta_garantida': 2.0,
#     'demais': 141.0,
#     'hipotecas': 5.0,
#     'internegocios': 4.0},
#    'margem': {'agro': 294.0,
#     'autos': 55.0,
#     'capital_de_giro': 80.0,
#     'comex': 1056.0,
#     'confirming': 209.0,
#     'conta_garantida': 46.0,
#     'demais': 193.0,
#     'hipotecas': 28.0,
#     'internegocios': 58.0},
#    'rwa': {'agro': 9186.0,
#     'autos': 1321.0,
#     'capital_de_giro': 3330.0,
#     'comex': 33518.0,
#     'confirming': 3442.0,
#     'conta_garantida': 1753.0,
#     'demais': 5319.0,
#     'hipotecas': 1307.0,
#     'internegocios': 2155.0}},
#   'comissoes': {'comissoes': {'adquirencia': 164.0,
#     'capitalizacao': 10.0,
#     'cartoes': 39.0,
#     'cash': 0.0,
#     'demais': 1478.0,
#     'fianca': 498.0,
#     'fx': 48.0,
#     'mercado_de_capitais': 264.0,
#     'seguros_open': 39.0,
#     'seguros_related': 16.0}},
#   'captacoes': {'spread': {'captacoes_comex': 2.6,
#     'cdb': 0.4,
#     'contamax': 12.9,
#     'dav': 6.1,
#     'demais': 4.4,
#     'letras': 2.5,
#     'time_deposit': 0.8},
#    'carteira': {'captacoes_comex': 2071.0,
#     'cdb': 41079.0,
#     'contamax': 6038.0,
#     'dav': 3103.0,
#     'demais': 3526.0,
#     'letras': 7197.0,
#     'time_deposit': 2829.0},
#    'margem': {'captacoes_comex': 81.0,
#     'cdb': 159.0,
#     'contamax': 898.0,
#     'dav': 194.0,
#     'demais': 94.0,
#     'letras': 179.0,
#     'time_deposit': 22.0}},
#   'cascada': {'cascada': {'bai': 5035.0,
#     'bdi': 3315.0,
#     'demais_ativos': 0.0,
#     'eficiencia': 11.6,
#     'impostos': -1720.0,
#     'mob': 6376.0,
#     'mol': 5797.0,
#     'oryp': -20.0,
#     'pdd': -579.0,
#     'rorwa': 3.3,
#     'rwa': 99616.0,
#     'taxa_impositiva': 34.2,
#     'total_gastos': -742.0},
#    'ppto': {'ppto_bai': 4987.0,
#     'ppto_bdi': 3300.0,
#     'ppto_demais_ativos': 0.0,
#     'ppto_impostos': -1687.0,
#     'ppto_mob': 6302.0,
#     'ppto_mol': 5809.0,
#     'ppto_oryp': -19.0,
#     'ppto_pdd': -493.0,
#     'ppto_total_gastos': -803.0},
#    'atingimento': {'atingimento_bai': 101.0,
#     'atingimento_bdi': 100.5,
#     'atingimento_demais_ativos': 0.0,
#     'atingimento_impostos': 102.0,
#     'atingimento_mob': 101.2,
#     'atingimento_mol': 99.8,
#     'atingimento_oryp': 105.3,
#     'atingimento_pdd': 117.4,
#     'atingimento_total_gastos': 92.4}}},
#  'scib': {'credito': {'carteira': {'agro': 2352.0,
#     'autos': 264.0,
#     'capital_de_giro': 4073.0,
#     'cartoes': 164.0,
#     'comex': 32579.0,
#     'confirming': 16530.0,
#     'demais': 103476.0,
#     'hipotecas': 345.0,
#     'internegocios': 15828.0},
#    'spread': {'agro': 1.6,
#     'autos': 4.1,
#     'capital_de_giro': 2.1,
#     'cartoes': 2.0,
#     'comex': 1.4,
#     'confirming': 1.8,
#     'demais': 202.8,
#     'hipotecas': 2.4,
#     'internegocios': 1.0},
#    'provisao': {'agro': 2.0,
#     'autos': 0.0,
#     'capital_de_giro': 340.0,
#     'cartoes': 0.0,
#     'comex': 6.0,
#     'confirming': 897.0,
#     'demais': 956.0,
#     'hipotecas': 0.0,
#     'internegocios': 9.0},
#    'margem': {'agro': 39.0,
#     'autos': 11.0,
#     'capital_de_giro': 85.0,
#     'cartoes': 3.0,
#     'comex': 460.0,
#     'confirming': 301.0,
#     'demais': 283.0,
#     'hipotecas': 8.0,
#     'internegocios': 213.0},
#    'rwa': {'agro': 1029.0,
#     'autos': 238.0,
#     'capital_de_giro': 2237.0,
#     'cartoes': 88.0,
#     'comex': 12667.0,
#     'confirming': 3804.0,
#     'demais': 3872.0,
#     'hipotecas': 262.0,
#     'internegocios': 12836.0}},
#   'comissoes': {'comissoes': {'cash': 0.0,
#     'comex': 191.0,
#     'corretagem': 0.0,
#     'demais': 633.0,
#     'fianca': 0.0,
#     'fx': 0.0,
#     'mercado_de_capitais': 60.0}},
#   'captacoes': {'spread': {'captacoes_comex': 0.3,
#     'cdb': 0.3,
#     'contamax': 8.6,
#     'dav': 7.4,
#     'demais': 21.8,
#     'letras': 2.8,
#     'lf': 0.0,
#     'time_deposit': 0.4},
#    'carteira': {'captacoes_comex': 115973.0,
#     'cdb': 91061.0,
#     'contamax': 5534.0,
#     'dav': 4592.0,
#     'demais': 1658.0,
#     'letras': 3778.0,
#     'lf': 1276.0,
#     'time_deposit': 14084.0},
#    'margem': {'captacoes_comex': 314.0,
#     'cdb': 271.0,
#     'contamax': 473.0,
#     'dav': 340.0,
#     'demais': 47.0,
#     'letras': 107.0,
#     'lf': 11.0,
#     'time_deposit': 51.0}},
#   'cascada': {'cascada': {'bai': 6681.0,
#     'bdi': 4518.0,
#     'demais_ativos': 0.0,
#     'eficiencia': 26.2,
#     'impostos': -2163.0,
#     'mob': 9229.0,
#     'mol': 9120.0,
#     'oryp': -19.0,
#     'pdd': -109.0,
#     'rorwa': 3.7,
#     'rwa': 122660.0,
#     'taxa_impositiva': 32.4,
#     'total_gastos': -2420.0},
#    'ppto': {'ppto_bai': 6669.0,
#     'ppto_bdi': 4842.0,
#     'ppto_demais_ativos': 0.0,
#     'ppto_impostos': -2232.0,
#     'ppto_mob': 9113.0,
#     'ppto_mol': 8998.0,
#     'ppto_oryp': -21.0,
#     'ppto_pdd': -115.0,
#     'ppto_total_gastos': -2308.0},
#    'atingimento': {'atingimento_bai': 100.2,
#     'atingimento_bdi': 93.3,
#     'atingimento_demais_ativos': 0.0,
#     'atingimento_impostos': 96.9,
#     'atingimento_mob': 101.3,
#     'atingimento_mol': 101.4,
#     'atingimento_oryp': 90.5,
#     'atingimento_pdd': 94.8,
#     'atingimento_total_gastos': 104.9}}},
#  'private': {'credito': {'carteira': {'agro': 68.0,
#     'autos': 558.0,
#     'capital_de_giro': 39.0,
#     'cartoes': 486.0,
#     'comex': 2956.0,
#     'cp': 57.0,
#     'demais': 1550.0,
#     'hipotecas': 1863.0,
#     'internegocios': 471.0},
#    'spread': {'agro': 3.4,
#     'autos': 2.3,
#     'capital_de_giro': 1.0,
#     'cartoes': 2.2,
#     'comex': 1.5,
#     'cp': 3.7,
#     'demais': 63.1,
#     'hipotecas': 1.2,
#     'internegocios': 1.9},
#    'provisao': {'agro': 0.0,
#     'autos': 0.0,
#     'capital_de_giro': 0.0,
#     'cartoes': 2.0,
#     'comex': 1.0,
#     'cp': 0.0,
#     'demais': 2.0,
#     'hipotecas': 0.0,
#     'internegocios': 0.0},
#    'margem': {'agro': 2.0,
#     'autos': 13.0,
#     'capital_de_giro': 0.0,
#     'cartoes': 10.0,
#     'comex': 45.0,
#     'cp': 2.0,
#     'demais': 5.0,
#     'hipotecas': 22.0,
#     'internegocios': 9.0},
#    'rwa': {'agro': 30.0,
#     'autos': 520.0,
#     'capital_de_giro': 6.0,
#     'cartoes': 131.0,
#     'comex': 1258.0,
#     'cp': 14.0,
#     'demais': 34.0,
#     'hipotecas': 703.0,
#     'internegocios': 0.0}},
#   'comissoes': {'comissoes': {'cartoes': 32.0,
#     'comex': 0.0,
#     'demais': 208.0,
#     'esfera': 0.0,
#     'fundos': 24.0,
#     'fx': 526.0,
#     'mercado_de_capitais': 0.0,
#     'previdencia': 0.0}},
#   'captacoes': {'spread': {'captacoes_comex': 0.0,
#     'cdb': 0.5,
#     'coe': 0.0,
#     'contamax': 12.4,
#     'dav': 5.5,
#     'demais': 1.5,
#     'letras': 0.4},
#    'carteira': {'captacoes_comex': 1539.0,
#     'cdb': 17431.0,
#     'coe': 947.0,
#     'contamax': 1106.0,
#     'dav': 129.0,
#     'demais': 1167.0,
#     'letras': 54189.0},
#    'margem': {'captacoes_comex': 0.0,
#     'cdb': 80.0,
#     'coe': 0.0,
#     'contamax': 137.0,
#     'dav': 7.0,
#     'demais': 1.0,
#     'letras': 202.0}},
#   'cascada': {'cascada': {'bai': 604.0,
#     'bdi': 388.0,
#     'demais_ativos': 0.0,
#     'eficiencia': 46.0,
#     'impostos': -216.0,
#     'mob': 1130.0,
#     'mol': 1126.0,
#     'oryp': -2.0,
#     'pdd': -4.0,
#     'rorwa': 5.6,
#     'rwa': 6890.0,
#     'taxa_impositiva': 35.8,
#     'total_gastos': -520.0},
#    'ppto': {'ppto_bai': 607.0,
#     'ppto_bdi': 392.0,
#     'ppto_demais_ativos': 0.0,
#     'ppto_impostos': -215.0,
#     'ppto_mob': 1124.0,
#     'ppto_mol': 1109.0,
#     'ppto_oryp': -2.0,
#     'ppto_pdd': -15.0,
#     'ppto_total_gastos': -500.0},
#    'atingimento': {'atingimento_bai': 99.5,
#     'atingimento_bdi': 99.0,
#     'atingimento_demais_ativos': 0.0,
#     'atingimento_impostos': 100.5,
#     'atingimento_mob': 100.5,
#     'atingimento_mol': 101.5,
#     'atingimento_oryp': 100.0,
#     'atingimento_pdd': 26.7,
#     'atingimento_total_gastos': 104.0}}},
#  'consumer': {'credito': {'carteira': {'autos': 64583.0,
#     'cp': 877.0,
#     'demais': 3874.0},
#    'spread': {'autos': 7.8, 'cp': 21.1, 'demais': 8.2},
#    'provisao': {'autos': 3891.0, 'cp': 0.0, 'demais': 0.0},
#    'margem': {'autos': 5045.0, 'cp': 185.0, 'demais': 315.0},
#    'rwa': {'autos': 49758.0, 'cp': 796.0, 'demais': 1234.0}},
#   'comissoes': {'comissoes': {'demais': 133.0,
#     'seguros_open': 0.0,
#     'seguros_related': 0.0,
#     'tarifas_de_credito': 0.0}},
#   'captacoes': {'spread': {'demais': 0.0},
#    'carteira': {'demais': 0.0},
#    'margem': {'demais': 0.0}},
#   'cascada': {'cascada': {'bai': 2012.0,
#     'bdi': 1209.0,
#     'demais_ativos': 0.0,
#     'eficiencia': 15.9,
#     'impostos': -803.0,
#     'mob': 7218.0,
#     'mol': 3467.0,
#     'oryp': -307.0,
#     'pdd': -3751.0,
#     'rorwa': 1.7,
#     'rwa': 70232.0,
#     'taxa_impositiva': 39.9,
#     'total_gastos': -1148.0},
#    'ppto': {'ppto_bai': 2012.0,
#     'ppto_bdi': 1161.0,
#     'ppto_demais_ativos': 0.0,
#     'ppto_impostos': -851.0,
#     'ppto_mob': 7268.0,
#     'ppto_mol': 3457.0,
#     'ppto_oryp': -297.0,
#     'ppto_pdd': -3811.0,
#     'ppto_total_gastos': -1148.0},
#    'atingimento': {'atingimento_bai': 100.0,
#     'atingimento_bdi': 104.1,
#     'atingimento_demais_ativos': 0.0,
#     'atingimento_impostos': 94.4,
#     'atingimento_mob': 99.3,
#     'atingimento_mol': 100.3,
#     'atingimento_oryp': 103.4,
#     'atingimento_pdd': 98.4,
#     'atingimento_total_gastos': 100.0}}},
#  'total': {'cascada': {'cascada': {'bai': 25843.0,
#     'bdi': 15236.0,
#     'demais_ativos': -314.0,
#     'eficiencia': 31.9,
#     'impostos': -10607.0,
#     'mob': 81922.0,
#     'mol': 55393.0,
#     'oryp': -3107.0,
#     'pdd': -26529.0,
#     'rorwa': 2.5,
#     'rwa': 600644.0,
#     'taxa_impositiva': 41.0,
#     'total_gastos': -26129.0},
#    'ppto': {'ppto_bai': 27120.0,
#     'ppto_bdi': 16480.0,
#     'ppto_demais_ativos': -548.0,
#     'ppto_impostos': -10640.0,
#     'ppto_mob': 82847.0,
#     'ppto_mol': 56498.0,
#     'ppto_oryp': -3130.0,
#     'ppto_pdd': -26349.0,
#     'ppto_total_gastos': -25700.0},
#    'atingimento': {'atingimento_bai': 95.3,
#     'atingimento_bdi': 92.5,
#     'atingimento_demais_ativos': 57.3,
#     'atingimento_impostos': 99.7,
#     'atingimento_mob': 98.9,
#     'atingimento_mol': 98.0,
#     'atingimento_oryp': 99.3,
#     'atingimento_pdd': 100.7,
#     'atingimento_total_gastos': 101.7}}}}

# %%
# Cálculo do spread correto
for segmento in segmentos:
    for topico in dict_indicadores[segmento].keys():
        if topico in ["credito", "captacoes"]:
            for abertura in dict_indicadores[segmento][topico]["spread"]:
                try:
                    dict_indicadores[segmento][topico]["spread"][abertura] = round(dict_indicadores[segmento][topico]["margem"][abertura] / dict_indicadores[segmento][topico]["carteira"][abertura] * 100, 2)
                except:
                    dict_indicadores[segmento][topico]["spread"][abertura] = 0

# %%
dict_indicadores
# Out:
# {'especial': {'credito': {'carteira': {'autos': 4970.0,
#     'cartoes': 20157.0,
#     'cheque_especial': 1747.0,
#     'consignado': 38458.0,
#     'cp': 6964.0,
#     'demais': 67.0,
#     'hipotecas': 11632.0},
#    'spread': {'autos': 9.36,
#     'cartoes': 17.02,
#     'cheque_especial': 89.52,
#     'consignado': 8.57,
#     'cp': 22.33,
#     'demais': 26.87,
#     'hipotecas': 1.47},
#    'provisao': {'autos': 380.0,
#     'cartoes': 3317.0,
#     'cheque_especial': 477.0,
#     'consignado': 1957.0,
#     'cp': 2917.0,
#     'demais': 22.0,
#     'hipotecas': 68.0},
#    'margem': {'autos': 465.0,
#     'cartoes': 3430.0,
#     'cheque_especial': 1564.0,
#     'consignado': 3294.0,
#     'cp': 1555.0,
#     'demais': 18.0,
#     'hipotecas': 171.0},
#    'rwa': {'autos': 3519.0,
#     'cartoes': 7841.0,
#     'cheque_especial': 1067.0,
#     'consignado': 22553.0,
#     'cp': 2496.0,
#     'demais': 28.0,
#     'hipotecas': 3579.0}},
#   'comissoes': {'comissoes': {'capitalizacao': 448.0,
#     'cartoes': 1654.0,
#     'demais': 1822.0,
#     'esfera': 33.0,
#     'fidelizacao_inss': 266.0,
#     'seguros_open': 597.0,
#     'seguros_related': 491.0,
#     'tecban': 0.0}},
#   'captacoes': {'spread': {'cdb': 0.54,
#     'contamax': 12.65,
#     'dav': 6.23,
#     'demais': 6.29,
#     'letras': 0.62,
#     'poupanca': 1.68},
#    'carteira': {'cdb': 5517.0,
#     'contamax': 11509.0,
#     'dav': 706.0,
#     'demais': 859.0,
#     'letras': 800.0,
#     'poupanca': 18838.0},
#    'margem': {'cdb': 30.0,
#     'contamax': 1456.0,
#     'dav': 44.0,
#     'demais': 54.0,
#     'letras': 5.0,
#     'poupanca': 316.0}},
#   'cascada': {'cascada': {'bai': -1848.0,
#     'bdi': -1735.0,
#     'demais_ativos': -185.0,
#     'eficiencia': 39.0,
#     'impostos': 113.0,
#     'mob': 14768.0,
#     'mol': 5070.0,
#     'oryp': -972.0,
#     'pdd': -9698.0,
#     'rorwa': -4.2,
#     'rwa': 41286.9,
#     'taxa_impositiva': 6.1,
#     'total_gastos': -5761.0},
#    'ppto': {'ppto_bai': 1579.0,
#     'ppto_bdi': 1638.0,
#     'ppto_demais_ativos': -144.0,
#     'ppto_impostos': -59.0,
#     'ppto_mob': 15351.0,
#     'ppto_mol': 5580.0,
#     'ppto_oryp': -1298.0,
#     'ppto_pdd': -9771.0,
#     'ppto_total_gastos': -5717.0},
#    'atingimento': {'atingimento_bai': -117.0,
#     'atingimento_bdi': -105.9,
#     'atingimento_demais_ativos': 128.5,
#     'atingimento_impostos': -191.5,
#     'atingimento_mob': 96.2,
#     'atingimento_mol': 90.9,
#     'atingimento_oryp': 74.9,
#     'atingimento_pdd': 99.3,
#     'atingimento_total_gastos': 100.8}}},
#  'prospera': {'credito': {'carteira': {'autos': 184.0,
#     'cartoes': 182.0,
#     'cheque_especial': 18.0,
#     'consignado': 1494.0,
#     'cp': 44.0,
#     'demais': 0.0,
#     'hipotecas': 107.0,
#     'microcredito': 2719.0},
#    'spread': {'autos': 9.24,
#     'cartoes': 17.58,
#     'cheque_especial': 94.44,
#     'consignado': 6.89,
#     'cp': 22.73,
#     'demais': 0,
#     'hipotecas': 1.87,
#     'microcredito': 36.12},
#    'provisao': {'autos': 28.0,
#     'cartoes': 181.0,
#     'cheque_especial': 10.0,
#     'consignado': 96.0,
#     'cp': 34.0,
#     'demais': 0.0,
#     'hipotecas': 0.0,
#     'microcredito': 213.0},
#    'margem': {'autos': 17.0,
#     'cartoes': 32.0,
#     'cheque_especial': 17.0,
#     'consignado': 103.0,
#     'cp': 10.0,
#     'demais': 0.0,
#     'hipotecas': 2.0,
#     'microcredito': 982.0},
#    'rwa': {'autos': 130.0,
#     'cartoes': 71.0,
#     'cheque_especial': 11.0,
#     'consignado': 876.0,
#     'cp': 16.0,
#     'demais': 0.0,
#     'hipotecas': 33.0,
#     'microcredito': 1411.0}},
#   'comissoes': {'comissoes': {'capitalizacao': 12.0,
#     'cartoes': 76.0,
#     'demais': 37.0,
#     'esfera': 0.0,
#     'fidelizacao_inss': 0.0,
#     'seguros_open': 12.0,
#     'seguros_related': 22.0,
#     'tecban': 2.0}},
#   'captacoes': {'spread': {'cdb': 0.0,
#     'contamax': 12.84,
#     'dav': 6.67,
#     'demais': 16.67,
#     'letras': 0.0,
#     'poupanca': 1.66},
#    'carteira': {'cdb': 81.0,
#     'contamax': 218.0,
#     'dav': 75.0,
#     'demais': 12.0,
#     'letras': 7.0,
#     'poupanca': 1145.0},
#    'margem': {'cdb': 0.0,
#     'contamax': 28.0,
#     'dav': 5.0,
#     'demais': 2.0,
#     'letras': 0.0,
#     'poupanca': 19.0}},
#   'cascada': {'cascada': {'bai': 333.0,
#     'bdi': 176.0,
#     'demais_ativos': -1.0,
#     'eficiencia': 35.7,
#     'impostos': -157.0,
#     'mob': 1269.0,
#     'mol': 857.0,
#     'oryp': -70.0,
#     'pdd': -412.0,
#     'rorwa': 15.4,
#     'rwa': 1143.1,
#     'taxa_impositiva': 47.1,
#     'total_gastos': -453.0},
#    'ppto': {'ppto_bai': 733.0,
#     'ppto_bdi': 456.0,
#     'ppto_demais_ativos': -8.0,
#     'ppto_impostos': -277.0,
#     'ppto_mob': 1666.0,
#     'ppto_mol': 1276.0,
#     'ppto_oryp': -95.0,
#     'ppto_pdd': -390.0,
#     'ppto_total_gastos': -440.0},
#    'atingimento': {'atingimento_bai': 45.4,
#     'atingimento_bdi': 38.6,
#     'atingimento_demais_ativos': 12.5,
#     'atingimento_impostos': 56.7,
#     'atingimento_mob': 76.2,
#     'atingimento_mol': 67.2,
#     'atingimento_oryp': 73.7,
#     'atingimento_pdd': 105.6,
#     'atingimento_total_gastos': 103.0}}},
#  'select': {'credito': {'carteira': {'agro': 7002.0,
#     'autos': 3906.0,
#     'cartoes': 27769.0,
#     'cheque_especial': 2610.0,
#     'comex': 2111.0,
#     'consignado': 19940.0,
#     'cp': 6817.0,
#     'demais': 18710.0,
#     'hipotecas': 53263.0},
#    'spread': {'agro': 5.83,
#     'autos': 6.86,
#     'cartoes': 9.76,
#     'cheque_especial': 79.92,
#     'comex': 2.61,
#     'consignado': 8.15,
#     'cp': 22.56,
#     'demais': 1.54,
#     'hipotecas': 1.22},
#    'provisao': {'agro': 210.0,
#     'autos': 200.0,
#     'cartoes': 1585.0,
#     'cheque_especial': 327.0,
#     'comex': 4.0,
#     'consignado': 552.0,
#     'cp': 2269.0,
#     'demais': 78.0,
#     'hipotecas': 208.0},
#    'margem': {'agro': 408.0,
#     'autos': 268.0,
#     'cartoes': 2711.0,
#     'cheque_especial': 2086.0,
#     'comex': 55.0,
#     'consignado': 1625.0,
#     'cp': 1538.0,
#     'demais': 288.0,
#     'hipotecas': 652.0},
#    'rwa': {'agro': 3944.0,
#     'autos': 2766.0,
#     'cartoes': 10801.0,
#     'cheque_especial': 1594.0,
#     'comex': 1175.0,
#     'consignado': 11694.0,
#     'cp': 2443.0,
#     'demais': 7542.0,
#     'hipotecas': 16390.0}},
#   'comissoes': {'comissoes': {'aaa': 62.0,
#     'capitalizacao': 1439.0,
#     'cartoes': 2153.0,
#     'demais': 4789.0,
#     'esfera': 373.0,
#     'seguros_open': 781.0,
#     'seguros_related': 661.0,
#     'tecban': 12.0}},
#   'captacoes': {'spread': {'captacoes_comex': 5.93,
#     'cdb': 0.75,
#     'contamax': 12.67,
#     'dav': 6.22,
#     'demais': 0.21,
#     'letras': 1.34,
#     'poupanca': 1.65},
#    'carteira': {'captacoes_comex': 118.0,
#     'cdb': 68322.0,
#     'contamax': 19871.0,
#     'dav': 498.0,
#     'demais': 30864.0,
#     'letras': 20373.0,
#     'poupanca': 34844.0},
#    'margem': {'captacoes_comex': 7.0,
#     'cdb': 512.0,
#     'contamax': 2518.0,
#     'dav': 31.0,
#     'demais': 64.0,
#     'letras': 274.0,
#     'poupanca': 575.0}},
#   'cascada': {'cascada': {'bai': 4504.0,
#     'bdi': 2328.0,
#     'demais_ativos': -74.0,
#     'eficiencia': 39.6,
#     'impostos': -2176.0,
#     'mob': 18966.0,
#     'mol': 12919.0,
#     'oryp': -834.0,
#     'pdd': -6047.0,
#     'rorwa': 3.9,
#     'rwa': 59090.2,
#     'taxa_impositiva': 48.3,
#     'total_gastos': -7507.0},
#    'ppto': {'ppto_bai': 4680.0,
#     'ppto_bdi': 2590.0,
#     'ppto_demais_ativos': -163.0,
#     'ppto_impostos': -2090.0,
#     'ppto_mob': 18511.0,
#     'ppto_mol': 12669.0,
#     'ppto_oryp': -479.0,
#     'ppto_pdd': -5841.0,
#     'ppto_total_gastos': -7347.0},
#    'atingimento': {'atingimento_bai': 96.2,
#     'atingimento_bdi': 89.9,
#     'atingimento_demais_ativos': 45.4,
#     'atingimento_impostos': 104.1,
#     'atingimento_mob': 102.5,
#     'atingimento_mol': 102.0,
#     'atingimento_oryp': 174.1,
#     'atingimento_pdd': 103.5,
#     'atingimento_total_gastos': 102.2}}},
#  'pj': {'credito': {'carteira': {'agro': 1169.0,
#     'autos': 4791.0,
#     'capital_de_giro': 30441.0,
#     'cartoes': 4088.0,
#     'comex': 15184.0,
#     'confirming': 985.0,
#     'conta_garantida': 3113.0,
#     'demais': 23184.0,
#     'hipotecas': 2377.0,
#     'internegocios': 834.0},
#    'spread': {'agro': 4.88,
#     'autos': 5.41,
#     'capital_de_giro': 9.36,
#     'cartoes': 14.9,
#     'comex': 3.17,
#     'confirming': 3.55,
#     'conta_garantida': 16.77,
#     'demais': 18.91,
#     'hipotecas': 2.31,
#     'internegocios': 1.2},
#    'provisao': {'agro': 4.0,
#     'autos': 273.0,
#     'capital_de_giro': 1116.0,
#     'cartoes': 605.0,
#     'comex': 41.0,
#     'confirming': 11.0,
#     'conta_garantida': 154.0,
#     'demais': 806.0,
#     'hipotecas': 16.0,
#     'internegocios': 0.0},
#    'margem': {'agro': 57.0,
#     'autos': 259.0,
#     'capital_de_giro': 2850.0,
#     'cartoes': 609.0,
#     'comex': 481.0,
#     'confirming': 35.0,
#     'conta_garantida': 522.0,
#     'demais': 4385.0,
#     'hipotecas': 55.0,
#     'internegocios': 10.0},
#    'rwa': {'agro': 758.0,
#     'autos': 3617.0,
#     'capital_de_giro': 20078.0,
#     'cartoes': 2057.0,
#     'comex': 10603.0,
#     'confirming': 930.0,
#     'conta_garantida': 1942.0,
#     'demais': 5087.0,
#     'hipotecas': 1832.0,
#     'internegocios': 87.0}},
#   'comissoes': {'comissoes': {'adquirencia': 17.0,
#     'capitalizacao': 28.0,
#     'cartoes': 576.0,
#     'cash': 12.0,
#     'demais': 2661.0,
#     'esfera': 431.0,
#     'fx': 100.0,
#     'seguros_open': 576.0,
#     'seguros_related': 254.0,
#     'tecban': 82.0}},
#   'captacoes': {'spread': {'captacoes_comex': 3.61,
#     'cdb': 0.54,
#     'contamax': 12.84,
#     'dav': 6.08,
#     'demais': 2.26,
#     'letras': 5.18,
#     'poupanca': 1.73,
#     'time_deposit': 0.0},
#    'carteira': {'captacoes_comex': 83.0,
#     'cdb': 52686.0,
#     'contamax': 27870.0,
#     'dav': 7252.0,
#     'demais': 18436.0,
#     'letras': 2123.0,
#     'poupanca': 751.0,
#     'time_deposit': 68.0},
#    'margem': {'captacoes_comex': 3.0,
#     'cdb': 286.0,
#     'contamax': 3578.0,
#     'dav': 441.0,
#     'demais': 416.0,
#     'letras': 110.0,
#     'poupanca': 13.0,
#     'time_deposit': 0.0}},
#   'cascada': {'cascada': {'bai': 7859.0,
#     'bdi': 4675.0,
#     'demais_ativos': -11.0,
#     'eficiencia': 30.7,
#     'impostos': -3184.0,
#     'mob': 21408.0,
#     'mol': 15508.0,
#     'oryp': -1073.0,
#     'pdd': -5900.0,
#     'rorwa': 5.8,
#     'rwa': 80276.0,
#     'taxa_impositiva': 40.5,
#     'total_gastos': -6565.0},
#    'ppto': {'ppto_bai': 8253.0,
#     'ppto_bdi': 5040.0,
#     'ppto_demais_ativos': -220.0,
#     'ppto_impostos': -3213.0,
#     'ppto_mob': 21926.0,
#     'ppto_mol': 16014.0,
#     'ppto_oryp': -1093.0,
#     'ppto_pdd': -5911.0,
#     'ppto_total_gastos': -6448.0},
#    'atingimento': {'atingimento_bai': 95.2,
#     'atingimento_bdi': 92.8,
#     'atingimento_demais_ativos': 5.0,
#     'atingimento_impostos': 99.1,
#     'atingimento_mob': 97.6,
#     'atingimento_mol': 96.8,
#     'atingimento_oryp': 98.2,
#     'atingimento_pdd': 99.8,
#     'atingimento_total_gastos': 101.8}}},
#  'corporate': {'credito': {'carteira': {'agro': 12673.0,
#     'autos': 1621.0,
#     'capital_de_giro': 2212.0,
#     'comex': 49167.0,
#     'confirming': 5140.0,
#     'conta_garantida': 804.0,
#     'demais': 39558.0,
#     'hipotecas': 1318.0,
#     'internegocios': 3598.0},
#    'spread': {'agro': 2.32,
#     'autos': 3.39,
#     'capital_de_giro': 3.62,
#     'comex': 2.15,
#     'confirming': 4.07,
#     'conta_garantida': 5.72,
#     'demais': 0.49,
#     'hipotecas': 2.12,
#     'internegocios': 1.61},
#    'provisao': {'agro': 8.0,
#     'autos': 0.0,
#     'capital_de_giro': 19.0,
#     'comex': 4.0,
#     'confirming': 21.0,
#     'conta_garantida': 2.0,
#     'demais': 141.0,
#     'hipotecas': 5.0,
#     'internegocios': 4.0},
#    'margem': {'agro': 294.0,
#     'autos': 55.0,
#     'capital_de_giro': 80.0,
#     'comex': 1056.0,
#     'confirming': 209.0,
#     'conta_garantida': 46.0,
#     'demais': 193.0,
#     'hipotecas': 28.0,
#     'internegocios': 58.0},
#    'rwa': {'agro': 9186.0,
#     'autos': 1321.0,
#     'capital_de_giro': 3330.0,
#     'comex': 33518.0,
#     'confirming': 3442.0,
#     'conta_garantida': 1753.0,
#     'demais': 5319.0,
#     'hipotecas': 1307.0,
#     'internegocios': 2155.0}},
#   'comissoes': {'comissoes': {'adquirencia': 164.0,
#     'capitalizacao': 10.0,
#     'cartoes': 39.0,
#     'cash': 0.0,
#     'demais': 1478.0,
#     'fianca': 498.0,
#     'fx': 48.0,
#     'mercado_de_capitais': 264.0,
#     'seguros_open': 39.0,
#     'seguros_related': 16.0}},
#   'captacoes': {'spread': {'captacoes_comex': 3.91,
#     'cdb': 0.39,
#     'contamax': 14.87,
#     'dav': 6.25,
#     'demais': 2.67,
#     'letras': 2.49,
#     'time_deposit': 0.78},
#    'carteira': {'captacoes_comex': 2071.0,
#     'cdb': 41079.0,
#     'contamax': 6038.0,
#     'dav': 3103.0,
#     'demais': 3526.0,
#     'letras': 7197.0,
#     'time_deposit': 2829.0},
#    'margem': {'captacoes_comex': 81.0,
#     'cdb': 159.0,
#     'contamax': 898.0,
#     'dav': 194.0,
#     'demais': 94.0,
#     'letras': 179.0,
#     'time_deposit': 22.0}},
#   'cascada': {'cascada': {'bai': 5035.0,
#     'bdi': 3315.0,
#     'demais_ativos': 0.0,
#     'eficiencia': 11.6,
#     'impostos': -1720.0,
#     'mob': 6376.0,
#     'mol': 5797.0,
#     'oryp': -20.0,
#     'pdd': -579.0,
#     'rorwa': 3.3,
#     'rwa': 99616.0,
#     'taxa_impositiva': 34.2,
#     'total_gastos': -742.0},
#    'ppto': {'ppto_bai': 4987.0,
#     'ppto_bdi': 3300.0,
#     'ppto_demais_ativos': 0.0,
#     'ppto_impostos': -1687.0,
#     'ppto_mob': 6302.0,
#     'ppto_mol': 5809.0,
#     'ppto_oryp': -19.0,
#     'ppto_pdd': -493.0,
#     'ppto_total_gastos': -803.0},
#    'atingimento': {'atingimento_bai': 101.0,
#     'atingimento_bdi': 100.5,
#     'atingimento_demais_ativos': 0.0,
#     'atingimento_impostos': 102.0,
#     'atingimento_mob': 101.2,
#     'atingimento_mol': 99.8,
#     'atingimento_oryp': 105.3,
#     'atingimento_pdd': 117.4,
#     'atingimento_total_gastos': 92.4}}},
#  'scib': {'credito': {'carteira': {'agro': 2352.0,
#     'autos': 264.0,
#     'capital_de_giro': 4073.0,
#     'cartoes': 164.0,
#     'comex': 32579.0,
#     'confirming': 16530.0,
#     'demais': 103476.0,
#     'hipotecas': 345.0,
#     'internegocios': 15828.0},
#    'spread': {'agro': 1.66,
#     'autos': 4.17,
#     'capital_de_giro': 2.09,
#     'cartoes': 1.83,
#     'comex': 1.41,
#     'confirming': 1.82,
#     'demais': 0.27,
#     'hipotecas': 2.32,
#     'internegocios': 1.35},
#    'provisao': {'agro': 2.0,
#     'autos': 0.0,
#     'capital_de_giro': 340.0,
#     'cartoes': 0.0,
#     'comex': 6.0,
#     'confirming': 897.0,
#     'demais': 956.0,
#     'hipotecas': 0.0,
#     'internegocios': 9.0},
#    'margem': {'agro': 39.0,
#     'autos': 11.0,
#     'capital_de_giro': 85.0,
#     'cartoes': 3.0,
#     'comex': 460.0,
#     'confirming': 301.0,
#     'demais': 283.0,
#     'hipotecas': 8.0,
#     'internegocios': 213.0},
#    'rwa': {'agro': 1029.0,
#     'autos': 238.0,
#     'capital_de_giro': 2237.0,
#     'cartoes': 88.0,
#     'comex': 12667.0,
#     'confirming': 3804.0,
#     'demais': 3872.0,
#     'hipotecas': 262.0,
#     'internegocios': 12836.0}},
#   'comissoes': {'comissoes': {'cash': 0.0,
#     'comex': 191.0,
#     'corretagem': 0.0,
#     'demais': 633.0,
#     'fianca': 0.0,
#     'fx': 0.0,
#     'mercado_de_capitais': 60.0}},
#   'captacoes': {'spread': {'captacoes_comex': 0.27,
#     'cdb': 0.3,
#     'contamax': 8.55,
#     'dav': 7.4,
#     'demais': 2.83,
#     'letras': 2.83,
#     'lf': 0.86,
#     'time_deposit': 0.36},
#    'carteira': {'captacoes_comex': 115973.0,
#     'cdb': 91061.0,
#     'contamax': 5534.0,
#     'dav': 4592.0,
#     'demais': 1658.0,
#     'letras': 3778.0,
#     'lf': 1276.0,
#     'time_deposit': 14084.0},
#    'margem': {'captacoes_comex': 314.0,
#     'cdb': 271.0,
#     'contamax': 473.0,
#     'dav': 340.0,
#     'demais': 47.0,
#     'letras': 107.0,
#     'lf': 11.0,
#     'time_deposit': 51.0}},
#   'cascada': {'cascada': {'bai': 6681.0,
#     'bdi': 4518.0,
#     'demais_ativos': 0.0,
#     'eficiencia': 26.2,
#     'impostos': -2163.0,
#     'mob': 9229.0,
#     'mol': 9120.0,
#     'oryp': -19.0,
#     'pdd': -109.0,
#     'rorwa': 3.7,
#     'rwa': 122660.0,
#     'taxa_impositiva': 32.4,
#     'total_gastos': -2420.0},
#    'ppto': {'ppto_bai': 6669.0,
#     'ppto_bdi': 4842.0,
#     'ppto_demais_ativos': 0.0,
#     'ppto_impostos': -2232.0,
#     'ppto_mob': 9113.0,
#     'ppto_mol': 8998.0,
#     'ppto_oryp': -21.0,
#     'ppto_pdd': -115.0,
#     'ppto_total_gastos': -2308.0},
#    'atingimento': {'atingimento_bai': 100.2,
#     'atingimento_bdi': 93.3,
#     'atingimento_demais_ativos': 0.0,
#     'atingimento_impostos': 96.9,
#     'atingimento_mob': 101.3,
#     'atingimento_mol': 101.4,
#     'atingimento_oryp': 90.5,
#     'atingimento_pdd': 94.8,
#     'atingimento_total_gastos': 104.9}}},
#  'private': {'credito': {'carteira': {'agro': 68.0,
#     'autos': 558.0,
#     'capital_de_giro': 39.0,
#     'cartoes': 486.0,
#     'comex': 2956.0,
#     'cp': 57.0,
#     'demais': 1550.0,
#     'hipotecas': 1863.0,
#     'internegocios': 471.0},
#    'spread': {'agro': 2.94,
#     'autos': 2.33,
#     'capital_de_giro': 0.0,
#     'cartoes': 2.06,
#     'comex': 1.52,
#     'cp': 3.51,
#     'demais': 0.32,
#     'hipotecas': 1.18,
#     'internegocios': 1.91},
#    'provisao': {'agro': 0.0,
#     'autos': 0.0,
#     'capital_de_giro': 0.0,
#     'cartoes': 2.0,
#     'comex': 1.0,
#     'cp': 0.0,
#     'demais': 2.0,
#     'hipotecas': 0.0,
#     'internegocios': 0.0},
#    'margem': {'agro': 2.0,
#     'autos': 13.0,
#     'capital_de_giro': 0.0,
#     'cartoes': 10.0,
#     'comex': 45.0,
#     'cp': 2.0,
#     'demais': 5.0,
#     'hipotecas': 22.0,
#     'internegocios': 9.0},
#    'rwa': {'agro': 30.0,
#     'autos': 520.0,
#     'capital_de_giro': 6.0,
#     'cartoes': 131.0,
#     'comex': 1258.0,
#     'cp': 14.0,
#     'demais': 34.0,
#     'hipotecas': 703.0,
#     'internegocios': 0.0}},
#   'comissoes': {'comissoes': {'cartoes': 32.0,
#     'comex': 0.0,
#     'demais': 208.0,
#     'esfera': 0.0,
#     'fundos': 24.0,
#     'fx': 526.0,
#     'mercado_de_capitais': 0.0,
#     'previdencia': 0.0}},
#   'captacoes': {'spread': {'captacoes_comex': 0.0,
#     'cdb': 0.46,
#     'coe': 0.0,
#     'contamax': 12.39,
#     'dav': 5.43,
#     'demais': 0.09,
#     'letras': 0.37},
#    'carteira': {'captacoes_comex': 1539.0,
#     'cdb': 17431.0,
#     'coe': 947.0,
#     'contamax': 1106.0,
#     'dav': 129.0,
#     'demais': 1167.0,
#     'letras': 54189.0},
#    'margem': {'captacoes_comex': 0.0,
#     'cdb': 80.0,
#     'coe': 0.0,
#     'contamax': 137.0,
#     'dav': 7.0,
#     'demais': 1.0,
#     'letras': 202.0}},
#   'cascada': {'cascada': {'bai': 604.0,
#     'bdi': 388.0,
#     'demais_ativos': 0.0,
#     'eficiencia': 46.0,
#     'impostos': -216.0,
#     'mob': 1130.0,
#     'mol': 1126.0,
#     'oryp': -2.0,
#     'pdd': -4.0,
#     'rorwa': 5.6,
#     'rwa': 6890.0,
#     'taxa_impositiva': 35.8,
#     'total_gastos': -520.0},
#    'ppto': {'ppto_bai': 607.0,
#     'ppto_bdi': 392.0,
#     'ppto_demais_ativos': 0.0,
#     'ppto_impostos': -215.0,
#     'ppto_mob': 1124.0,
#     'ppto_mol': 1109.0,
#     'ppto_oryp': -2.0,
#     'ppto_pdd': -15.0,
#     'ppto_total_gastos': -500.0},
#    'atingimento': {'atingimento_bai': 99.5,
#     'atingimento_bdi': 99.0,
#     'atingimento_demais_ativos': 0.0,
#     'atingimento_impostos': 100.5,
#     'atingimento_mob': 100.5,
#     'atingimento_mol': 101.5,
#     'atingimento_oryp': 100.0,
#     'atingimento_pdd': 26.7,
#     'atingimento_total_gastos': 104.0}}},
#  'consumer': {'credito': {'carteira': {'autos': 64583.0,
#     'cp': 877.0,
#     'demais': 3874.0},
#    'spread': {'autos': 7.81, 'cp': 21.09, 'demais': 8.13},
#    'provisao': {'autos': 3891.0, 'cp': 0.0, 'demais': 0.0},
#    'margem': {'autos': 5045.0, 'cp': 185.0, 'demais': 315.0},
#    'rwa': {'autos': 49758.0, 'cp': 796.0, 'demais': 1234.0}},
#   'comissoes': {'comissoes': {'demais': 133.0,
#     'seguros_open': 0.0,
#     'seguros_related': 0.0,
#     'tarifas_de_credito': 0.0}},
#   'captacoes': {'spread': {'demais': 0},
#    'carteira': {'demais': 0.0},
#    'margem': {'demais': 0.0}},
#   'cascada': {'cascada': {'bai': 2012.0,
#     'bdi': 1209.0,
#     'demais_ativos': 0.0,
#     'eficiencia': 15.9,
#     'impostos': -803.0,
#     'mob': 7218.0,
#     'mol': 3467.0,
#     'oryp': -307.0,
#     'pdd': -3751.0,
#     'rorwa': 1.7,
#     'rwa': 70232.0,
#     'taxa_impositiva': 39.9,
#     'total_gastos': -1148.0},
#    'ppto': {'ppto_bai': 2012.0,
#     'ppto_bdi': 1161.0,
#     'ppto_demais_ativos': 0.0,
#     'ppto_impostos': -851.0,
#     'ppto_mob': 7268.0,
#     'ppto_mol': 3457.0,
#     'ppto_oryp': -297.0,
#     'ppto_pdd': -3811.0,
#     'ppto_total_gastos': -1148.0},
#    'atingimento': {'atingimento_bai': 100.0,
#     'atingimento_bdi': 104.1,
#     'atingimento_demais_ativos': 0.0,
#     'atingimento_impostos': 94.4,
#     'atingimento_mob': 99.3,
#     'atingimento_mol': 100.3,
#     'atingimento_oryp': 103.4,
#     'atingimento_pdd': 98.4,
#     'atingimento_total_gastos': 100.0}}},
#  'total': {'cascada': {'cascada': {'bai': 25843.0,
#     'bdi': 15236.0,
#     'demais_ativos': -314.0,
#     'eficiencia': 31.9,
#     'impostos': -10607.0,
#     'mob': 81922.0,
#     'mol': 55393.0,
#     'oryp': -3107.0,
#     'pdd': -26529.0,
#     'rorwa': 2.5,
#     'rwa': 600644.0,
#     'taxa_impositiva': 41.0,
#     'total_gastos': -26129.0},
#    'ppto': {'ppto_bai': 27120.0,
#     'ppto_bdi': 16480.0,
#     'ppto_demais_ativos': -548.0,
#     'ppto_impostos': -10640.0,
#     'ppto_mob': 82847.0,
#     'ppto_mol': 56498.0,
#     'ppto_oryp': -3130.0,
#     'ppto_pdd': -26349.0,
#     'ppto_total_gastos': -25700.0},
#    'atingimento': {'atingimento_bai': 95.3,
#     'atingimento_bdi': 92.5,
#     'atingimento_demais_ativos': 57.3,
#     'atingimento_impostos': 99.7,
#     'atingimento_mob': 98.9,
#     'atingimento_mol': 98.0,
#     'atingimento_oryp': 99.3,
#     'atingimento_pdd': 100.7,
#     'atingimento_total_gastos': 101.7}}}}

# %%
import json

with open("dict_indicadores.json", "w", encoding="utf-8") as f:
    json.dump(dict_indicadores, f, indent=4, ensure_ascii=False)
